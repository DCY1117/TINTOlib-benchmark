# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
#import cv2
import gc
import matplotlib.pyplot as plt
#import openslide
#from openslide.deepzoom import DeepZoomGenerator
import tifffile as tifi
import sklearn
import tensorflow as tf
import seaborn as sns
from PIL import Image
import random


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,mean_absolute_percentage_error

from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model

from sklearn.model_selection import train_test_split
from keras.applications import vgg16, vgg19, resnet50, mobilenet, inception_resnet_v2, densenet, inception_v3, xception, nasnet, ResNet152V2
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, InputLayer, LayerNormalization
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.optimizers import SGD, Adam, Adadelta, Adamax
from keras import layers, models, Model
from keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError
from keras.layers import Input, Activation,MaxPooling2D, Concatenate, AveragePooling2D

from imblearn.over_sampling import RandomOverSampler

#Models of TINTOlib
from TINTOlib.tinto import TINTO
from TINTOlib.supertml import SuperTML
from TINTOlib.igtd import IGTD
from TINTOlib.refined import REFINED
from TINTOlib.barGraph import BarGraph
from TINTOlib.distanceMatrix import DistanceMatrix
from TINTOlib.combination import Combination

# %%
SEED = 64

# SET RANDOM SEED FOR REPRODUCIBILITY
os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Create variable to store dataset name
dataset_name = 'gas'
results_path = f'logs/{dataset_name}/MLP_Multiclass'

# %%
df = pd.read_csv(f"../Datasets_benchmark/Multiclass/{dataset_name}.csv")

# %% [markdown]
# LOAD AND PREPROCESS

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        ...
#        'V121', 'V122', 'V123', 'V124', 'V125', 'V126', 'V127', 'V128', 'V129',
#        'Class'],
#       dtype='object', length=130)

# %%
# get last column number of unique values
n_classes = df.iloc[:,-1].nunique()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import os
import cv2

# Function to load and preprocess data
def load_and_preprocess_data(images_folder, image_model, problem_type):

    # Generate the images if the folder does not exist
    if not os.path.exists(images_folder):
        #Generate thet images
        image_model.generateImages(df, images_folder)
    else:
        print("The images are already generated")

    img_paths = os.path.join(images_folder,problem_type+".csv")

    print(img_paths)
    
    imgs = pd.read_csv(img_paths)

    # Update image paths
    imgs["images"] = images_folder + "/" + imgs["images"]

    # Combine datasets
    combined_dataset = pd.concat([imgs, df], axis=1)

    # Split data
    df_x = combined_dataset.drop(df.columns[-1], axis=1).drop("class", axis=1)
    df_y = combined_dataset["class"]

    X_train, X_val, y_train, y_val = train_test_split(df_x, df_y, test_size=0.20, random_state=SEED)
    X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.50, random_state=SEED)

    # Numerical data
    X_train_num = X_train.drop("images", axis=1)
    X_val_num = X_val.drop("images", axis=1)
    X_test_num = X_test.drop("images", axis=1)

    # Image data
    X_train_img = np.array([cv2.imread(img) for img in X_train["images"]])
    X_val_img = np.array([cv2.imread(img) for img in X_val["images"]])
    X_test_img = np.array([cv2.imread(img) for img in X_test["images"]])

    # Create a MinMaxScaler object
    scaler = MinMaxScaler()

    # Scale numerical data
    X_train_num = pd.DataFrame(scaler.fit_transform(X_train_num), columns=X_train_num.columns)
    X_val_num = pd.DataFrame(scaler.transform(X_val_num), columns=X_val_num.columns)
    X_test_num = pd.DataFrame(scaler.transform(X_test_num), columns=X_test_num.columns)


    #ONE HOT ENCODING FOR MULTICLASS PROBLEMS
    onehot_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

    onehot_encoder.fit(y_train.values.reshape(-1, 1))

    # Transform the target variable using one-hot encoding
    y_train = onehot_encoder.transform(y_train.values.reshape(-1, 1))
    y_val = onehot_encoder.transform(y_val.values.reshape(-1, 1))
    y_test = onehot_encoder.transform(y_test.values.reshape(-1, 1))

    attributes = len(X_train_num.columns)
    imgs_shape = X_train_img[0].shape

    print("Images shape: ",imgs_shape)
    print("Attributres: ",attributes)
    pixels=X_train_img[0].shape[0]
    print("Image size (pixels):", pixels)

    return X_train_num, X_val_num, X_test_num, X_train_img, X_val_img, X_test_img, y_train, y_val, y_test, imgs_shape, attributes, onehot_encoder

# %% [markdown]
# MODEL ARCHITECTURES

# %%
# MLP
def create_model1(attributes):
    model1 = Sequential([
        Input(shape=(attributes,)),
        Dense(16, activation='relu'),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(n_classes, activation='softmax')  # Output layer for multiclass classification
    ])
    return model1

# %%
def create_model2(attributes):
    model2 = Sequential([
        Input(shape=(attributes,)),
        Dense(attributes, activation='relu'),
        Dense(int(attributes/2), activation='relu'),
        Dense(int(attributes/4), activation='relu'),
        Dense(n_classes, activation='softmax')  # Output layer for multiclass classification
    ])
    return model2

# %%
def create_model3(attributes):

    dropout = 0.1

    ff_inputs = Input(shape = (attributes,))
    # * START BRANCH 1
    mlp_1 = Dense(1024, activation='relu')(ff_inputs)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(512, activation='relu')(ff_inputs)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(256, activation='relu')(mlp_1)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(128, activation='relu')(mlp_1)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(64, activation='relu')(mlp_1)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(32, activation='relu')(mlp_1)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    mlp_1 = Dense(16, activation='relu')(mlp_1)
    mlp_1 = BatchNormalization()(mlp_1)
    mlp_1 = Dropout(dropout)(mlp_1)

    # * START BRANCH 2
    mlp_2 = Dense(1024, activation='relu')(ff_inputs)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(512, activation='relu')(ff_inputs)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(256, activation='relu')(mlp_2)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(128, activation='relu')(mlp_2)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(64, activation='relu')(mlp_2)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(32, activation='relu')(mlp_2)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    mlp_2 = Dense(16, activation='relu')(mlp_2)
    mlp_2 = BatchNormalization()(mlp_2)
    mlp_2 = Dropout(dropout)(mlp_2)

    merged_tabular = Concatenate(axis=1)([mlp_1, mlp_2])

    model_output = Dense(32, activation='relu')(merged_tabular)
    model_output = Dense(n_classes, activation='softmax')(model_output)

    model3 = Model(inputs=ff_inputs, outputs=model_output)

    return model3

# %% [markdown]
# METRICS

# %%
import tensorflow.keras.backend as K

METRICS = [
    tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name = 'precision'),
    tf.keras.metrics.Recall(name = 'recall'),
    tf.keras.metrics.AUC(name = 'auc'),
    tf.keras.metrics.AUC(name='prc', curve='PR'),  # precision-recall curve
]

# %% [markdown]
# COMPILE AND FIT

# %%
from tensorflow.keras.callbacks import EarlyStopping

def compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, model_name, batch_size=32, epochs=200, lr=1e-3):

    opt = Adam(learning_rate=lr)

    # Define the early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_accuracy',  # Monitor the validation loss
        min_delta=0.001,     # Minimum change in the monitored quantity to qualify as an improvement
        patience=20,          # Number of epochs with no improvement after which training will be stopped
        verbose=1,           # Print messages when the callback takes an action
        mode='max',           # Training will stop when the quantity monitored has stopped decreasing
        restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
    )

    
    model.compile(
        loss="categorical_crossentropy",
        optimizer=opt,
        metrics=METRICS
    )

    model_history = model.fit(
        x=X_train_num, y=y_train,
        validation_data=(X_val_num, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    os.makedirs(f"models/{dataset_name}/{model_name}", exist_ok=True)

    plt.figure()  # Start a new figure
    plt.plot(model_history.history['loss'], color = 'red', label = 'loss')
    plt.plot(model_history.history['val_loss'], color = 'green', label = 'val loss')
    plt.legend(loc = 'upper right')
    plt.savefig(f"models/{dataset_name}/{model_name}/loss_plot.png")

    plt.figure()  # Start a new figure
    plt.plot(model_history.history['accuracy'], color = 'red', label = 'accuracy')
    plt.plot(model_history.history['val_accuracy'], color = 'green', label = 'val accuracy')
    plt.legend(loc = 'upper right')
    plt.savefig(f"models/{dataset_name}/{model_name}/accuracy_plot.png")

    plt.figure()  # Start a new figure
    plt.plot(model_history.history['auc'], color = 'red', label = 'auc')
    plt.plot(model_history.history['val_auc'], color = 'green', label = 'val auc')
    plt.legend(loc = 'upper right')
    plt.savefig(f"models/{dataset_name}/{model_name}/auc_plot.png")

    # Save the model
    os.makedirs(f"models/{dataset_name}/{model_name}", exist_ok=True)
    model.save(f"models/{dataset_name}/{model_name}/model_{dataset_name}.keras")

    # Evaluate the model on the training set
    train_scores = model.evaluate(X_train_num, y_train)

    # Evaluate the model on the validation set
    val_scores = model.evaluate(X_val_num, y_val)

    # Evaluate the model on the test set
    score_test = model.evaluate(X_test_num, y_test)

    # Save training, validation, and test scores
    metrics = {
        'train_loss': train_scores[0],
        'train_accuracy': train_scores[1],
        'train_precision': train_scores[2],
        'train_recall': train_scores[3],
        'train_auc': train_scores[4],
        'train_prc': train_scores[5],
        'val_loss': val_scores[0],
        'val_accuracy': val_scores[1],
        'val_precision': val_scores[2],
        'val_recall': val_scores[3],
        'val_auc': val_scores[4],
        'val_prc': val_scores[5],
        'test_loss': score_test[0],
        'test_accuracy': score_test[1],
        'test_precision': score_test[2],
        'test_recall': score_test[3],
        'test_auc': score_test[4],
        'test_prc': score_test[5]
    }

    # Save metrics to a file
    os.makedirs(f'{results_path}/{model_name}', exist_ok=True)
    with open(f'{results_path}/{model_name}/{dataset_name}_metrics.txt', 'w') as f:
        for key, value in metrics.items():
            f.write(f'{key}: {value}\n')

    return metrics

# %%
def safe_compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test,dataset_name, model_name, batch_size=32, epochs=200, lr=1e-3):
    try:
        if model is None:
            print(f"Model {model_name} is None")
            return None
        else:
            metrics = compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test,dataset_name, model_name, batch_size, epochs, lr)
            return metrics
    except Exception as e:
        print(f"Failed to compile and fit {model_name}: {str(e)}")
        return None

# %%
def try_create_model(create_model_func, attributes):
    try:
        model = create_model_func(attributes)
        return model
    except Exception as e:
        print(f"Error creating model: {str(e)}")
        return None

# %% [markdown]
# TEST

# %%
#Select the model and the parameters
problem_type = "supervised"
#image_model = REFINED(problem= problem_type,hcIterations=5)
image_model = TINTO(problem= problem_type, blur=True)
#image_model = IGTD(problem= problem_type)
#image_model = BarGraph(problem= problem_type)
#image_model = DistanceMatrix(problem= problem_type)
#image_model = Combination(problem= problem_type)
#image_model = SuperTML(problem= problem_type)

#Define the dataset path and the folder where the images will be saved
images_folder = f"../HyNNImages/Regression/images_{dataset_name}_IGTD"

# %%
#Select the model and the parameters
problem_type = "supervised"
image_model = TINTO(problem= problem_type, blur=True)

#Define the dataset path and the folder where the images will be saved
images_folder = f"../HyNNImages/Multiclass/{dataset_name}/images_{dataset_name}_TINTO"

# %%
X_train_num, X_val_num, X_test_num, X_train_img, X_val_img, X_test_img, y_train, y_val, y_test, imgs_shape, attributes, one_hot_encoder = load_and_preprocess_data(images_folder, image_model, problem_type)
# Out:
# The images are already generated
# ../HyNNImages/Multiclass/gas/images_gas_TINTO\supervised.csv
# Images shape:  (20, 20, 3)
# Attributres:  129
# Image size (pixels): 20

# %%
model1 = try_create_model(create_model1, attributes)
model2 = try_create_model(create_model2, attributes)
model3 = try_create_model(create_model3, attributes)

# %%
# Example usage with two models
model1_metrics = safe_compile_and_fit(model1, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_Model1")
model2_metrics = safe_compile_and_fit(model2, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_Model2")
model3_metrics = safe_compile_and_fit(model3, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_Model3")

# Print comparison of metrics only for models that ran successfully
if model1_metrics:
    print("Model 1 Metrics:", model1_metrics)
if model2_metrics:
    print("Model 2 Metrics:", model2_metrics)
if model3_metrics:
    print("Model 3 Metrics:", model3_metrics)
# Out:
# Epoch 1/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3725 - auc: 0.6873 - loss: 1.5980 - prc: 0.3919 - precision: 0.6960 - recall: 0.0724 - val_accuracy: 0.6751 - val_auc: 0.9290 - val_loss: 1.5150 - val_prc: 0.7788 - val_precision: 0.9138 - val_recall: 0.4342
# Epoch 2/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6878 - auc: 0.9400 - loss: 0.8241 - prc: 0.7999 - precision: 0.9144 - recall: 0.4687 - val_accuracy: 0.8181 - val_auc: 0.9782 - val_loss: 2.3605 - val_prc: 0.9212 - val_precision: 0.9753 - val_recall: 0.6247
# Epoch 3/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.8070 - auc: 0.9765 - loss: 0.5289 - prc: 0.9144 - precision: 0.9615 - recall: 0.6295 - val_accuracy: 0.8965 - val_auc: 0.9882 - val_loss: 2.9140 - val_prc: 0.9585 - val_precision: 0.9753 - val_recall: 0.7088
# Epoch 4/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8590 - auc: 0.9849 - loss: 0.4230 - prc: 0.9453 - precision: 0.9539 - recall: 0.7119 - val_accuracy: 0.9065 - val_auc: 0.9895 - val_loss: 3.0781 - val_prc: 0.9662 - val_precision: 0.9557 - val_recall: 0.8059
# Epoch 5/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.8843 - auc: 0.9878 - loss: 0.3706 - prc: 0.9580 - precision: 0.9387 - recall: 0.8018 - val_accuracy: 0.9116 - val_auc: 0.9903 - val_loss: 3.0813 - val_prc: 0.9694 - val_precision: 0.9508 - val_recall: 0.8483
# Epoch 6/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.8953 - auc: 0.9893 - loss: 0.3378 - prc: 0.9636 - precision: 0.9347 - recall: 0.8392 - val_accuracy: 0.9260 - val_auc: 0.9912 - val_loss: 3.0344 - val_prc: 0.9731 - val_precision: 0.9529 - val_recall: 0.8720
# Epoch 7/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9081 - auc: 0.9902 - loss: 0.3130 - prc: 0.9682 - precision: 0.9361 - recall: 0.8644 - val_accuracy: 0.9346 - val_auc: 0.9920 - val_loss: 2.9733 - val_prc: 0.9764 - val_precision: 0.9550 - val_recall: 0.9008
# Epoch 8/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - auc: 0.9911 - loss: 0.2923 - prc: 0.9718 - precision: 0.9378 - recall: 0.8832 - val_accuracy: 0.9425 - val_auc: 0.9925 - val_loss: 2.8787 - val_prc: 0.9781 - val_precision: 0.9580 - val_recall: 0.9180
# Epoch 9/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.9231 - auc: 0.9918 - loss: 0.2736 - prc: 0.9747 - precision: 0.9441 - recall: 0.8969 - val_accuracy: 0.9446 - val_auc: 0.9929 - val_loss: 2.7564 - val_prc: 0.9794 - val_precision: 0.9576 - val_recall: 0.9252
# Epoch 10/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - accuracy: 0.9284 - auc: 0.9925 - loss: 0.2565 - prc: 0.9771 - precision: 0.9475 - recall: 0.9073 - val_accuracy: 0.9461 - val_auc: 0.9932 - val_loss: 2.5679 - val_prc: 0.9807 - val_precision: 0.9577 - val_recall: 0.9281
# Epoch 11/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9324 - auc: 0.9932 - loss: 0.2412 - prc: 0.9788 - precision: 0.9479 - recall: 0.9137 - val_accuracy: 0.9482 - val_auc: 0.9935 - val_loss: 2.3885 - val_prc: 0.9813 - val_precision: 0.9593 - val_recall: 0.9317
# Epoch 12/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.9371 - auc: 0.9937 - loss: 0.2253 - prc: 0.9809 - precision: 0.9504 - recall: 0.9218 - val_accuracy: 0.9490 - val_auc: 0.9938 - val_loss: 2.2232 - val_prc: 0.9818 - val_precision: 0.9594 - val_recall: 0.9353
# Epoch 13/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.9418 - auc: 0.9943 - loss: 0.2105 - prc: 0.9824 - precision: 0.9526 - recall: 0.9267 - val_accuracy: 0.9540 - val_auc: 0.9938 - val_loss: 2.1080 - val_prc: 0.9827 - val_precision: 0.9610 - val_recall: 0.9382
# Epoch 14/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9451 - auc: 0.9946 - loss: 0.1974 - prc: 0.9841 - precision: 0.9549 - recall: 0.9304 - val_accuracy: 0.9583 - val_auc: 0.9943 - val_loss: 2.0232 - val_prc: 0.9837 - val_precision: 0.9654 - val_recall: 0.9439
# Epoch 15/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9480 - auc: 0.9951 - loss: 0.1845 - prc: 0.9854 - precision: 0.9575 - recall: 0.9364 - val_accuracy: 0.9633 - val_auc: 0.9948 - val_loss: 1.9640 - val_prc: 0.9848 - val_precision: 0.9685 - val_recall: 0.9511
# Epoch 16/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9519 - auc: 0.9954 - loss: 0.1732 - prc: 0.9866 - precision: 0.9607 - recall: 0.9425 - val_accuracy: 0.9676 - val_auc: 0.9950 - val_loss: 1.9323 - val_prc: 0.9857 - val_precision: 0.9723 - val_recall: 0.9597
# Epoch 17/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.9571 - auc: 0.9959 - loss: 0.1615 - prc: 0.9883 - precision: 0.9655 - recall: 0.9483 - val_accuracy: 0.9705 - val_auc: 0.9951 - val_loss: 1.9062 - val_prc: 0.9862 - val_precision: 0.9731 - val_recall: 0.9619
# Epoch 18/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.9608 - auc: 0.9963 - loss: 0.1518 - prc: 0.9894 - precision: 0.9671 - recall: 0.9533 - val_accuracy: 0.9698 - val_auc: 0.9956 - val_loss: 1.8848 - val_prc: 0.9868 - val_precision: 0.9732 - val_recall: 0.9655
# Epoch 19/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.9638 - auc: 0.9966 - loss: 0.1431 - prc: 0.9904 - precision: 0.9716 - recall: 0.9561 - val_accuracy: 0.9727 - val_auc: 0.9957 - val_loss: 1.8754 - val_prc: 0.9872 - val_precision: 0.9747 - val_recall: 0.9691
# Epoch 20/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9668 - auc: 0.9968 - loss: 0.1356 - prc: 0.9910 - precision: 0.9732 - recall: 0.9606 - val_accuracy: 0.9734 - val_auc: 0.9958 - val_loss: 1.8391 - val_prc: 0.9875 - val_precision: 0.9754 - val_recall: 0.9705
# Epoch 21/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9698 - auc: 0.9970 - loss: 0.1280 - prc: 0.9916 - precision: 0.9743 - recall: 0.9628 - val_accuracy: 0.9727 - val_auc: 0.9959 - val_loss: 1.7968 - val_prc: 0.9880 - val_precision: 0.9761 - val_recall: 0.9705
# Epoch 22/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9723 - auc: 0.9971 - loss: 0.1221 - prc: 0.9921 - precision: 0.9761 - recall: 0.9656 - val_accuracy: 0.9748 - val_auc: 0.9960 - val_loss: 1.7538 - val_prc: 0.9885 - val_precision: 0.9776 - val_recall: 0.9734
# Epoch 23/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.9732 - auc: 0.9972 - loss: 0.1165 - prc: 0.9925 - precision: 0.9767 - recall: 0.9690 - val_accuracy: 0.9748 - val_auc: 0.9961 - val_loss: 1.7355 - val_prc: 0.9889 - val_precision: 0.9776 - val_recall: 0.9727
# Epoch 24/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.9748 - auc: 0.9975 - loss: 0.1115 - prc: 0.9930 - precision: 0.9776 - recall: 0.9703 - val_accuracy: 0.9748 - val_auc: 0.9961 - val_loss: 1.7094 - val_prc: 0.9890 - val_precision: 0.9776 - val_recall: 0.9734
# Epoch 25/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9755 - auc: 0.9975 - loss: 0.1077 - prc: 0.9931 - precision: 0.9788 - recall: 0.9720 - val_accuracy: 0.9684 - val_auc: 0.9961 - val_loss: 1.7111 - val_prc: 0.9889 - val_precision: 0.9703 - val_recall: 0.9626
# Epoch 26/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.9760 - auc: 0.9976 - loss: 0.1038 - prc: 0.9934 - precision: 0.9792 - recall: 0.9730 - val_accuracy: 0.9676 - val_auc: 0.9961 - val_loss: 1.7132 - val_prc: 0.9897 - val_precision: 0.9689 - val_recall: 0.9641
# Epoch 27/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.9771 - auc: 0.9977 - loss: 0.0993 - prc: 0.9937 - precision: 0.9800 - recall: 0.9735 - val_accuracy: 0.9684 - val_auc: 0.9962 - val_loss: 1.6792 - val_prc: 0.9899 - val_precision: 0.9724 - val_recall: 0.9641
# Epoch 28/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.9784 - auc: 0.9979 - loss: 0.0947 - prc: 0.9940 - precision: 0.9815 - recall: 0.9745 - val_accuracy: 0.9712 - val_auc: 0.9966 - val_loss: 1.6758 - val_prc: 0.9904 - val_precision: 0.9754 - val_recall: 0.9691
# Epoch 29/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - auc: 0.9980 - loss: 0.0911 - prc: 0.9944 - precision: 0.9819 - recall: 0.9751 - val_accuracy: 0.9792 - val_auc: 0.9964 - val_loss: 1.7165 - val_prc: 0.9907 - val_precision: 0.9805 - val_recall: 0.9748
# Epoch 30/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9787 - auc: 0.9980 - loss: 0.0867 - prc: 0.9947 - precision: 0.9825 - recall: 0.9758 - val_accuracy: 0.9792 - val_auc: 0.9971 - val_loss: 1.7082 - val_prc: 0.9923 - val_precision: 0.9798 - val_recall: 0.9784
# Epoch 31/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9795 - auc: 0.9981 - loss: 0.0841 - prc: 0.9950 - precision: 0.9832 - recall: 0.9767 - val_accuracy: 0.9799 - val_auc: 0.9972 - val_loss: 1.7450 - val_prc: 0.9925 - val_precision: 0.9805 - val_recall: 0.9763
# Epoch 32/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9797 - auc: 0.9983 - loss: 0.0802 - prc: 0.9955 - precision: 0.9832 - recall: 0.9782 - val_accuracy: 0.9734 - val_auc: 0.9971 - val_loss: 1.8288 - val_prc: 0.9920 - val_precision: 0.9783 - val_recall: 0.9720
# Epoch 33/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.9809 - auc: 0.9984 - loss: 0.0788 - prc: 0.9957 - precision: 0.9836 - recall: 0.9784 - val_accuracy: 0.9741 - val_auc: 0.9971 - val_loss: 1.8770 - val_prc: 0.9921 - val_precision: 0.9783 - val_recall: 0.9720
# Epoch 34/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy:
200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9853 - auc: 0.9988 - loss: 0.0578 - prc: 0.9967 - precision: 0.9868 - recall: 0.9835 - val_accuracy: 0.9835 - val_auc: 0.9978 - val_loss: 2.4038 - val_prc: 0.9936 - val_precision: 0.9834 - val_recall: 0.9820
# Epoch 45/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9855 - auc: 0.9989 - loss: 0.0573 - prc: 0.9968 - precision: 0.9871 - recall: 0.9835 - val_accuracy: 0.9835 - val_auc: 0.9979 - val_loss: 2.5315 - val_prc: 0.9938 - val_precision: 0.9835 - val_recall: 0.9835
# Epoch 46/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9859 - auc: 0.9988 - loss: 0.0548 - prc: 0.9968 - precision: 0.9874 - recall: 0.9839 - val_accuracy: 0.9835 - val_auc: 0.9979 - val_loss: 2.5848 - val_prc: 0.9939 - val_precision: 0.9835 - val_recall: 0.9835
# Epoch 47/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.9855 - auc: 0.9989 - loss: 0.0530 - prc: 0.9970 - precision: 0.9872 - recall: 0.9844 - val_accuracy: 0.9849 - val_auc: 0.9979 - val_loss: 2.6055 - val_prc: 0.9940 - val_precision: 0.9849 - val_recall: 0.9842
# Epoch 48/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9852 - auc: 0.9989 - loss: 0.0532 - prc: 0.9971 - precision: 0.9872 - recall: 0.9833 - val_accuracy: 0.9856 - val_auc: 0.9980 - val_loss: 2.6686 - val_prc: 0.9941 - val_precision: 0.9856 - val_recall: 0.9849
# Epoch 49/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.9854 - auc: 0.9991 - loss: 0.0510 - prc: 0.9973 - precision: 0.9872 - recall: 0.9845 - val_accuracy: 0.9842 - val_auc: 0.9976 - val_loss: 2.7548 - val_prc: 0.9931 - val_precision: 0.9842 - val_recall: 0.9842
# Epoch 50/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.9856 - auc: 0.9992 - loss: 0.0495 - prc: 0.9974 - precision: 0.9868 - recall: 0.9846 - val_accuracy: 0.9849 - val_auc: 0.9975 - val_loss: 2.8523 - val_prc: 0.9924 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 51/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9862 - auc: 0.9992 - loss: 0.0482 - prc: 0.9975 - precision: 0.9876 - recall: 0.9857 - val_accuracy: 0.9856 - val_auc: 0.9975 - val_loss: 2.9816 - val_prc: 0.9924 - val_precision: 0.9856 - val_recall: 0.9856
# Epoch 52/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.9851 - auc: 0.9992 - loss: 0.0487 - prc: 0.9974 - precision: 0.9865 - recall: 0.9844 - val_accuracy: 0.9856 - val_auc: 0.9979 - val_loss: 2.9489 - val_prc: 0.9935 - val_precision: 0.9856 - val_recall: 0.9856
# Epoch 53/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.9862 - auc: 0.9992 - loss: 0.0472 - prc: 0.9979 - precision: 0.9872 - recall: 0.9856 - val_accuracy: 0.9863 - val_auc: 0.9975 - val_loss: 2.9740 - val_prc: 0.9925 - val_precision: 0.9863 - val_recall: 0.9863
# Epoch 54/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9866 - auc: 0.9992 - loss: 0.0451 - prc: 0.9976 - precision: 0.9887 - recall: 0.9863 - val_accuracy: 0.9856 - val_auc: 0.9975 - val_loss: 2.9898 - val_prc: 0.9925 - val_precision: 0.9863 - val_recall: 0.9856
# Epoch 55/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - auc: 0.9995 - loss: 0.0232 - prc: 0.9988 - precision: 0.9949 - recall: 0.9939 - val_accuracy: 0.9892 - val_auc: 0.9981 - val_loss: 5.2286 - val_prc: 0.9950 - val_precision: 0.9906 - val_recall: 0.9885
# Epoch 99/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9930 - auc: 0.9998 - loss: 0.0231 - prc: 0.9994 - precision: 0.9939 - recall: 0.9929 - val_accuracy: 0.9899 - val_auc: 0.9981 - val_loss: 5.2678 - val_prc: 0.9950 - val_precision: 0.9906 - val_recall: 0.9899
# Epoch 100/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.9941 - auc: 0.9998 - loss: 0.0226 - prc: 0.9994 - precision: 0.9952 - recall: 0.9935 - val_accuracy: 0.9885 - val_auc: 0.9977 - val_loss: 5.5552 - val_prc: 0.9939 - val_precision: 0.9899 - val_recall: 0.9885
# Epoch 101/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.9938 - auc: 0.9996 - loss: 0.0230 - prc: 0.9988 - precision: 0.9945 - recall: 0.9931 - val_accuracy: 0.9885 - val_auc: 0.9982 - val_loss: 5.5619 - val_prc: 0.9951 - val_precision: 0.9885 - val_recall: 0.9885
# Epoch 102/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.9932 - auc: 0.9996 - loss: 0.0224 - prc: 0.9989 - precision: 0.9940 - recall: 0.9931 - val_accuracy: 0.9899 - val_auc: 0.9982 - val_loss: 5.7188 - val_prc: 0.9951 - val_precision: 0.9914 - val_recall: 0.9899
# Epoch 103/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9943 - auc: 0.9998 - loss: 0.0215 - prc: 0.9994 - precision: 0.9952 - recall: 0.9941 - val_accuracy: 0.9899 - val_auc: 0.9982 - val_loss: 5.8194 - val_prc: 0.9952 - val_precision: 0.9899 - val_recall: 0.9899
# Epoch 104/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - auc: 0.9998 - loss: 0.0212 - prc: 0.9995 - precision: 0.9953 - recall: 0.9937 - val_accuracy: 0.9892 - val_auc: 0.9982 - val_loss: 5.7885 - val_prc: 0.9951 - val_precision: 0.9892 - val_recall: 0.9892
# Epoch 105/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9943 - auc: 0.9998 - loss: 0.0207 - prc: 0.9995 - precision: 0.9955 - recall: 0.9940 - val_accuracy: 0.9892 - val_auc: 0.9982 - val_loss: 5.9507 - val_prc: 0.9951 - val_precision: 0.9899 - val_recall: 0.9885
# Epoch 105: early stopping
# Restoring model weights from the end of the best epoch: 85.
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - accuracy: 0.9929 - auc: 0.9993 - loss: 0.0359 - prc: 0.9981 - precision: 0.9935 - recall: 0.9925
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9926 - auc: 0.9992 - loss: 0.6158 - prc: 0.9979 - precision: 0.9943 - recall: 0.9904
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.9925 - auc: 0.9990 - loss: 0.0512 - prc: 0.9967 - precision: 0.9928 - recall: 0.9924
# Epoch 1/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6631 - auc: 0.9161 - loss: 1.2728 - prc: 0.7809 - precision: 0.9708 - recall: 0.4661 - val_accuracy: 0.8016 - val_auc: 0.9688 - val_loss: 1.0203 - val_prc: 0.9000 - val_precision: 0.9172 - val_recall: 0.7009
# Epoch 2/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8410 - auc: 0.9808 - loss: 0.4537 - prc: 0.9353 - precision: 0.9305 - recall: 0.7494 - val_accuracy: 0.8871 - val_auc: 0.9872 - val_loss: 0.5038 - val_prc: 0.9566 - val_precision: 0.9295 - val_recall: 0.8246
# Epoch 3/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.8948 - auc: 0.9884 - loss: 0.3349 - prc: 0.9621 - precision: 0.9306 - recall: 0.8526 - val_accuracy: 0.9080 - val_auc: 0.9898 - val_loss: 0.3153 - val_prc: 0.9664 - val_precision: 0.9319 - val_recall: 0.8555
# Epoch 4/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9285 - auc: 0.9926 - loss: 0.2485 - prc: 0.9773 - precision: 0.9486 - recall: 0.9047 - val_accuracy: 0.9597 - val_auc: 0.9944 - val_loss: 0.2015 - val_prc: 0.9850 - val_precision: 0.9660 - val_recall: 0.9389
# Epoch 5/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9528 - auc: 0.9949 - loss: 0.1841 - prc: 0.9861 - precision: 0.9637 - recall: 0.9383 - val_accuracy: 0.9526 - val_auc: 0.9940 - val_loss: 0.3602 - val_prc: 0.9836 - val_precision: 0.9651 - val_recall: 0.9353
# Epoch 6/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9614 - auc: 0.9960 - loss: 0.1495 - prc: 0.9893 - precision: 0.9696 - recall: 0.9530 - val_accuracy: 0.9633 - val_auc: 0.9951 - val_loss: 0.4126 - val_prc: 0.9869 - val_precision: 0.9679 - val_recall: 0.9533
# Epoch 7/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9675 - auc: 0.9970 - loss: 0.1241 - prc: 0.9918 - precision: 0.9729 - recall: 0.9616 - val_accuracy: 0.9806 - val_auc: 0.9966 - val_loss: 0.3826 - val_prc: 0.9909 - val_precision: 0.9855 - val_recall: 0.9777
# Epoch 8/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9741 - auc: 0.9976 - loss: 0.1017 - prc: 0.9935 - precision: 0.9787 - recall: 0.9704 - val_accuracy: 0.9756 - val_auc: 0.9970 - val_loss: 0.3049 - val_prc: 0.9917 - val_precision: 0.9797 - val_recall: 0.9734
# Epoch 9/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.9747 - auc: 0.9978 - loss: 0.0886 - prc: 0.9944 - precision: 0.9795 - recall: 0.9729 - val_accuracy: 0.9727 - val_auc: 0.9975 - val_loss: 0.3021 - val_prc: 0.9923 - val_precision: 0.9755 - val_recall: 0.9720
# Epoch 10/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9758 - auc: 0.9981 - loss: 0.0842 - prc: 0.9949 - precision: 0.9786 - recall: 0.9725 - val_accuracy: 0.9734 - val_auc: 0.9976 - val_loss: 0.2681 - val_prc: 0.9926 - val_precision: 0.9762 - val_recall: 0.9720
# Epoch 11/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.9769 - auc: 0.9985 - loss: 0.0770 - prc: 0.9953 - precision: 0.9802 - recall: 0.9752 - val_accuracy: 0.9748 - val_auc: 0.9977 - val_loss: 0.3621 - val_prc: 0.9935 - val_precision: 0.9769 - val_recall: 0.9712
# Epoch 12/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9790 - auc: 0.9987 - loss: 0.0698 - prc: 0.9964 - precision: 0.9809 - recall: 0.9775 - val_accuracy: 0.9741 - val_auc: 0.9981 - val_loss: 0.3670 - val_prc: 0.9939 - val_precision: 0.9755 - val_recall: 0.9720
# Epoch 13/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.9810 - auc: 0.9988 - loss: 0.0655 - prc: 0.9966 - precision: 0.9819 - recall: 0.9789 - val_accuracy: 0.9806 - val_auc: 0.9979 - val_loss: 0.4289 - val_prc: 0.9927 - val_precision: 0.9840 - val_recall: 0.9705
# Epoch 14/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0
200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9908 - auc: 0.9997 - loss: 0.0298 - prc: 0.9993 - precision: 0.9915 - recall: 0.9905 - val_accuracy: 0.9942 - val_auc: 0.9986 - val_loss: 0.0501 - val_prc: 0.9959 - val_precision: 0.9942 - val_recall: 0.9942
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.9929 - auc: 0.9993 - loss: 0.0337 - prc: 0.9984 - precision: 0.9931 - recall: 0.9927
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9953 - auc: 0.9998 - loss: 0.0225 - prc: 0.9993 - precision: 0.9974 - recall: 0.9948
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - auc: 0.9990 - loss: 0.0404 - prc: 0.9970 - precision: 0.9937 - recall: 0.9937
# Epoch 1/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.8026 - auc: 0.9652 - loss: 0.8902 - prc: 0.8988 - precision: 0.9502 - recall: 0.6835 - val_accuracy: 0.6370 - val_auc: 0.8944 - val_loss: 4.5268 - val_prc: 0.6955 - val_precision: 0.6667 - val_recall: 0.5838
# Epoch 2/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9189 - auc: 0.9916 - loss: 0.2591 - prc: 0.9713 - precision: 0.9389 - recall: 0.9012 - val_accuracy: 0.7304 - val_auc: 0.9578 - val_loss: 9.8234 - val_prc: 0.8592 - val_precision: 0.7546 - val_recall: 0.7096
# Epoch 3/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9318 - auc: 0.9939 - loss: 0.2109 - prc: 0.9792 - precision: 0.9520 - recall: 0.9179 - val_accuracy: 0.8368 - val_auc: 0.9751 - val_loss: 12.0459 - val_prc: 0.9235 - val_precision: 0.8595 - val_recall: 0.8267
# Epoch 4/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9433 - auc: 0.9953 - loss: 0.1750 - prc: 0.9844 - precision: 0.9559 - recall: 0.9311 - val_accuracy: 0.6592 - val_auc: 0.8903 - val_loss: 18.9775 - val_prc: 0.7329 - val_precision: 0.6808 - val_recall: 0.6564
# Epoch 5/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9509 - auc: 0.9955 - loss: 0.1556 - prc: 0.9857 - precision: 0.9606 - recall: 0.9423 - val_accuracy: 0.4910 - val_auc: 0.7452 - val_loss: 22.5575 - val_prc: 0.4269 - val_precision: 0.4966 - val_recall: 0.4795
# Epoch 6/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9549 - auc: 0.9970 - loss: 0.1367 - prc: 0.9893 - precision: 0.9638 - recall: 0.9480 - val_accuracy: 0.8641 - val_auc: 0.9877 - val_loss: 15.6856 - val_prc: 0.9573 - val_precision: 0.9267 - val_recall: 0.8447
# Epoch 7/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9541 - auc: 0.9968 - loss: 0.1378 - prc: 0.9890 - precision: 0.9619 - recall: 0.9485 - val_accuracy: 0.8620 - val_auc: 0.9849 - val_loss: 13.9420 - val_prc: 0.9487 - val_precision: 0.8734 - val_recall: 0.8483
# Epoch 8/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9573 - auc: 0.9967 - loss: 0.1340 - prc: 0.9894 - precision: 0.9654 - recall: 0.9520 - val_accuracy: 0.7671 - val_auc: 0.9663 - val_loss: 15.9960 - val_prc: 0.8877 - val_precision: 0.8149 - val_recall: 0.7247
# Epoch 9/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9643 - auc: 0.9977 - loss: 0.1083 - prc: 0.9921 - precision: 0.9703 - recall: 0.9577 - val_accuracy: 0.9267 - val_auc: 0.9922 - val_loss: 17.8251 - val_prc: 0.9760 - val_precision: 0.9570 - val_recall: 0.9130
# Epoch 10/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9665 - auc: 0.9976 - loss: 0.1078 - prc: 0.9926 - precision: 0.9707 - recall: 0.9610 - val_accuracy: 0.6039 - val_auc: 0.8190 - val_loss: 23.4278 - val_prc: 0.5567 - val_precision: 0.6052 - val_recall: 0.6039
# Epoch 11/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9658 - auc: 0.9984 - loss: 0.1024 - prc: 0.9939 - precision: 0.9717 - recall: 0.9591 - val_accuracy: 0.7685 - val_auc: 0.9333 - val_loss: 17.5705 - val_prc: 0.8155 - val_precision: 0.7744 - val_recall: 0.7649
# Epoch 12/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9684 - auc: 0.9981 - loss: 0.1010 - prc: 0.9935 - precision: 0.9744 - recall: 0.9645 - val_accuracy: 0.6786 - val_auc: 0.9129 - val_loss: 26.6714 - val_prc: 0.7765 - val_precision: 0.7000 - val_recall: 0.6542
# Epoch 13/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9701 - auc: 0.9978 - loss: 0.1001 - prc: 0.9932 - precision: 0.9748 - recall: 0.9648 - val_accuracy: 0.7534 - val_auc: 0.9278 - val_loss: 20.0717 - val_prc: 0.8497 - val_precision: 0.7822 - val_recall: 0.7513
# Epoch 14/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9711 - auc: 0.9983 - loss: 0.0899 - prc: 0.9947 - precision: 0.9752 - recall: 0.9682 - val_accuracy: 0.9116 - val_auc: 0.9809 - val_loss: 15.2278 - val_prc: 0.9404 - val_precision: 0.9200 - val_recall: 0.8929
# Epoch 15/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9715 - auc: 0.9985 - loss: 0.0884 - prc: 0.9952 - precision: 0.9757 - recall: 0.9680 - val_accuracy: 0.5866 - val_auc: 0.8980 - val_loss: 13.2306 - val_prc: 0.7247 - val_precision: 0.5908 - val_recall: 0.5751
# Epoch 16/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9728 - auc: 0.9985 - loss: 0.0844 - prc: 0.9953 - precision: 0.9764 - recall: 0.9698 - val_accuracy: 0.6772 - val_auc: 0.9287 - val_loss: 17.5947 - val_prc: 0.7801 - val_precision: 0.7272 - val_recall: 0.6362
# Epoch 17/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9749 - auc: 0.9988 - loss: 0.0771 - prc: 0.9959 - precision: 0.9790 - recall: 0.9717 - val_accuracy: 0.8260 - val_auc: 0.9805 - val_loss: 27.3321 - val_prc: 0.9264 - val_precision: 0.8450 - val_recall: 0.8152
# Epoch 18/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9731 - auc: 0.9984 - loss: 0.0849 - prc: 0.9954 - precision: 0.9771 - recall: 0.9707 - val_accuracy: 0.6794 - val_auc: 0.9022 - val_loss: 16.6349 - val_prc: 0.7791 - val_precision: 0.7142 - val_recall: 0.6592
# Epoch 19/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9728 - auc: 0.9984 - loss: 0.0820 - prc: 0.9950 - precision: 0.9775 - recall: 0.9707 - val_accuracy: 0.7347 - val_auc: 0.9608 - val_loss: 27.5952 - val_prc: 0.8720 - val_precision: 0.7562 - val_recall: 0.7247
# Epoch 20/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9776 - auc: 0.9991 - loss: 0.0662 - prc: 0.9972 - precision: 0.9811 - recall: 0.9763 - val_accuracy: 0.7743 - val_auc: 0.9085 - val_loss: 20.8460 - val_prc: 0.7986 - val_precision: 0.7846 - val_recall: 0.7671
# Epoch 21/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9738 - auc: 0.9988 - loss: 0.0801 - prc: 0.9959 - precision: 0.9764 - recall: 0.9704 - val_accuracy: 0.5191 - val_auc: 0.7780 - val_loss: 30.8044 - val_prc: 0.5195 - val_precision: 0.5248 - val_recall: 0.5176
# Epoch 22/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9767 - auc: 0.9991 - loss: 0.0645 - prc: 0.9973 - precision: 0.9804 - recall: 0.9749 - val_accuracy: 0.4378 - val_auc: 0.7107 - val_loss: 68.3203 - val_prc: 0.3775 - val_precision: 0.4403 - val_recall: 0.4349
# Epoch 23/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9766 - auc: 0.9990 - loss: 0.0734 - prc: 0.9967 - precision: 0.9794 - recall: 0.9751 - val_accuracy: 0.7103 - val_auc: 0.8613 - val_loss: 33.9066 - val_prc: 0.7002 - val_precision: 0.7162 - val_recall: 0.7038
# Epoch 24/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9787 - auc: 0.9987 - loss: 0.0704 - prc: 0.9963 - precision: 0.9826 - recall: 0.9769 - val_accuracy: 0.7168 - val_auc: 0.9022 - val_loss: 47.2722 - val_prc: 0.7326 - val_precision: 0.7199 - val_recall: 0.7096
# Epoch 25/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9812 - auc: 0.9992 - loss: 0.0604 - prc: 0.9972 - precision: 0.9825 - recall: 0.9792 - val_accuracy: 0.5758 - val_auc: 0.8072 - val_loss: 61.4241 - val_prc: 0.5286 - val_precision: 0.5768 - val_recall: 0.5723
# Epoch 26/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9793 - auc: 0.9992 - loss: 0.0604 - prc: 0.9975 - precision: 0.9821 - recall: 0.9779 - val_accuracy: 0.7297 - val_auc: 0.8953 - val_loss: 116.0604 - val_prc: 0.7825 - val_precision: 0.7421 - val_recall: 0.7261
# Epoch 27/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9817 - auc: 0.9993 - loss: 0.0553 - prc: 0.9976 - precision: 0.9833 - recall: 0.9795 - val_accuracy: 0.9087 - val_auc: 0.9938 - val_loss: 107.4285 - val_prc: 0.9769 - val_precision: 0.9136 - val_recall: 0.9051
# Epoch 28/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9824 - auc: 0.9995 - loss: 0.0532 - prc: 0.9982 - precision: 0.9854 - recall: 0.9799 - val_accuracy: 0.6556 - val_auc: 0.8632 - val_loss: 74.0429 - val_prc: 0.6484 - val_precision: 0.6584 - val_recall: 0.6485
# Epoch 29/200
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9822 - auc: 0.9993 - loss: 0.0492 - prc: 0.9978 - precision: 0.9845 - recall: 0.9810 - val_accuracy: 0.6082 - val_auc: 0.8150 - val_loss: 65.2162 - val_prc: 0.6979 - val_precision: 0.6447 - val_recall: 0.5766
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9262 - auc: 0.9940 - loss: 0.2218 - prc: 0.9793 - precision: 0.9459 - recall: 0.9086
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9276 - auc: 0.9949 - loss: 2.6238 - prc: 0.9819 - precision: 0.9571 - recall: 0.9125
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9312 - auc: 0.9959 - loss: 0.1932 - prc: 0.9845 - precision: 0.9599 - recall: 0.9201
# Model 1 Metrics: {'train_loss': 0.031789399683475494, 'train_accuracy': 0.9928109049797058, 'train_precision': 0.9933435320854187, 'train_recall': 0.9923616051673889, 'train_auc': 0.9994802474975586, 'train_prc': 0.9986462593078613, 'val_loss': 4.268626689910889, 'val_accuracy': 0.9913731217384338, 'val_precision': 0.9927849769592285, 'val_recall': 0.9892163872718811, 'val_auc': 0.9976304173469543, 'val_prc': 0.9934239387512207, 'test_loss': 0.048730604350566864, 'test_accuracy': 0.9935298562049866, 'test_precision': 0.9942404627799988, 'test_recall': 0.9928109049797058, 'test_auc': 0.9989562630653381, 'test_prc': 0.9967131614685059}
# Model 2 Metrics: {'train_loss': 0.027419166639447212, 'train_accuracy': 0.9941588640213013, 'train_precision': 0.9946942329406738, 'train_recall': 0.9939791560173035, 'train_auc': 0.9995421767234802, 'train_prc': 0.9987903833389282, 'val_loss': 0.043995462357997894, 'val_accuracy': 0.9935298562049866, 'val_precision': 0.9949567914009094, 'val_recall': 0.9928109049797058, 'val_auc': 0.9990088939666748, 'val_prc': 0.9970006346702576, 'test_loss': 0.03754393756389618, 'test_accuracy': 0.9935298562049866, 'test_precision': 0.9935298562049866, 'test_recall': 0.9935298562049866, 'test_auc': 0.9990246891975403, 'test_prc': 0.9970638155937195}
# Model 3 Metrics: {'train_loss': 0.21188823878765106, 'train_accuracy': 0.9272106289863586, 'train_precision': 0.9474127292633057, 'train_recall': 0.909866988658905, 'train_auc': 0.9945154190063477, 'train_prc': 0.9805088043212891, 'val_loss': 17.825145721435547, 'val_accuracy': 0.9266714453697205, 'val_precision': 0.9570459723472595, 'val_recall': 0.9130122065544128, 'val_auc': 0.9921529293060303, 'val_prc': 0.9760266542434692, 'test_loss': 0.20981881022453308, 'test_accuracy': 0.9237958192825317, 'test_precision': 0.9547169804573059, 'test_recall': 0.9094176888465881, 'test_auc': 0.994979739189148, 'test_prc': 0.9820648431777954}

# %%
def find_best_model(base_path):
    best_accuracy = float('-inf')
    best_folder = None

    # Walk through all directories and files in the base path
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file == f'{dataset_name}_metrics.txt':
                file_path = os.path.join(root, file)
                
                # Read metrics from the file
                with open(file_path, 'r') as f:
                    metrics = f.read()
                
                # Parse the metrics into a dictionary
                metrics_dict = {}
                for line in metrics.splitlines():
                    key, value = line.split(': ')
                    metrics_dict[key.strip()] = float(value.strip())
                
                # Check if the current folder has a better validation loss
                if metrics_dict['test_accuracy'] > best_accuracy:
                    best_accuracy = metrics_dict['test_accuracy']
                    best_folder = root
    
    return best_folder, best_accuracy

# %%
import os

def rename_folder(old_folder_path):
    # Extract the base name of the old folder
    folder_name = os.path.basename(old_folder_path)
    
    # Create the new folder name by prepending "best_"
    new_folder_name = f"BEST_{folder_name}"
    
    # Get the parent directory of the old folder
    parent_dir = os.path.dirname(old_folder_path)
    
    # Create the full path for the new folder
    new_folder_path = os.path.join(parent_dir, new_folder_name)
    
    # Rename the folder
    os.rename(old_folder_path, new_folder_path)
    
    return new_folder_path

# %%
# Usage
base_path = f"logs/{dataset_name}/MLP_Multiclass"
best_folder, best_accuracy = find_best_model(base_path)
best_folder = rename_folder(best_folder)
print(f"Best model folder: {best_folder}")
print(f"Best Accuracy: {best_accuracy}")
# Out:
# Best model folder: logs/gas/MLP_Multiclass\BEST_TINTO_Model1
# Best Accuracy: 0.9935298562049866
