# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
#import cv2
import gc
import matplotlib.pyplot as plt
#import openslide
#from openslide.deepzoom import DeepZoomGenerator
import tifffile as tifi
import sklearn
import tensorflow as tf
import seaborn as sns
from PIL import Image
import random


from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score,mean_absolute_percentage_error

from keras_preprocessing.image import ImageDataGenerator
from keras.models import load_model
from keras import ops
import keras

from sklearn.model_selection import train_test_split
from keras.applications import vgg16, vgg19, resnet50, mobilenet, inception_resnet_v2, densenet, inception_v3, xception, nasnet, ResNet152V2
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, InputLayer, LayerNormalization
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.optimizers import SGD, Adam, Adadelta, Adamax
from keras import layers, models, Model
from keras.losses import MeanAbsoluteError, MeanAbsolutePercentageError
from keras.layers import Input, Activation,MaxPooling2D, Concatenate, AveragePooling2D, Lambda

from imblearn.over_sampling import RandomOverSampler

#Models of TINTOlib
from TINTOlib.tinto import TINTO
from TINTOlib.supertml import SuperTML
from TINTOlib.igtd import IGTD
from TINTOlib.refined import REFINED
from TINTOlib.barGraph import BarGraph
from TINTOlib.distanceMatrix import DistanceMatrix
from TINTOlib.combination import Combination

# %%
SEED = 64

# SET RANDOM SEED FOR REPRODUCIBILITY
os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Create variable to store dataset name
dataset_name = 'california_housing'
results_path = f'logs/{dataset_name}/ViT_Regression'

# %%
df = pd.read_csv(f"../Datasets_benchmark/{dataset_name}.csv")

# %%
df.shape
# Out:
# (20640, 9)

# %% [markdown]
# LOAD AND PREPROCESS

# %%
from sklearn.preprocessing import MinMaxScaler
import os
import cv2

# Function to load and preprocess data
def load_and_preprocess_data(images_folder, image_model, problem_type):

    # Generate the images if the folder does not exist
    if not os.path.exists(images_folder):
        #Generate thet images
        image_model.generateImages(df, images_folder)
    else:
        print("The images are already generated")

    img_paths = os.path.join(images_folder,problem_type+".csv")

    print(img_paths)
    
    imgs = pd.read_csv(img_paths)

    # Update image paths
    imgs["images"] = images_folder + "/" + imgs["images"]

    # Combine datasets
    combined_dataset = pd.concat([imgs, df], axis=1)

    # Split data
    df_x = combined_dataset.drop(df.columns[-1], axis=1).drop("values", axis=1)
    df_y = combined_dataset["values"]

    X_train, X_val, y_train, y_val = train_test_split(df_x, df_y, test_size=0.40, random_state=SEED)
    X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.50, random_state=SEED)

    # Numerical data
    X_train_num = X_train.drop("images", axis=1)
    X_val_num = X_val.drop("images", axis=1)
    X_test_num = X_test.drop("images", axis=1)

    # Image data
    X_train_img = np.array([cv2.imread(img) for img in X_train["images"]])
    X_val_img = np.array([cv2.imread(img) for img in X_val["images"]])
    X_test_img = np.array([cv2.imread(img) for img in X_test["images"]])

    # Create a MinMaxScaler object
    scaler = MinMaxScaler()

    # Scale numerical data
    X_train_num = pd.DataFrame(scaler.fit_transform(X_train_num), columns=X_train_num.columns)
    X_val_num = pd.DataFrame(scaler.transform(X_val_num), columns=X_val_num.columns)
    X_test_num = pd.DataFrame(scaler.transform(X_test_num), columns=X_test_num.columns)

    attributes = len(X_train_num.columns)
    imgs_shape = X_train_img[0].shape

    print("Images shape: ",imgs_shape)
    print("Attributres: ",attributes)
    pixels=X_train_img[0].shape[0]
    print("Image size (pixels):", pixels)

    return X_train_num, X_val_num, X_test_num, X_train_img, X_val_img, X_test_img, y_train, y_val, y_test, imgs_shape, attributes

# %% [markdown]
# MODEL ARCHITECTURES

# %%
def pair(t):
    return t if isinstance(t, tuple) else (t, t)

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        input_shape = ops.shape(images)
        batch_size = input_shape[0]
        height = input_shape[1]
        width = input_shape[2]
        channels = input_shape[3]
        num_patches_h = height // self.patch_size
        num_patches_w = width // self.patch_size
        patches = keras.ops.image.extract_patches(images, size=(self.patch_size,self.patch_size))
        patches = ops.reshape(
            patches,
            (
                batch_size,
                num_patches_h * num_patches_w,
                self.patch_size * self.patch_size * channels,
            ),
        )
        return patches

    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, emb_dropout):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches + 1, output_dim=projection_dim
        )
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, projection_dim),
            initializer="random_normal",
            trainable=True
        )
        self.dropout = layers.Dropout(rate=emb_dropout)

    def call(self, patch):
        positions = ops.expand_dims(
            ops.arange(start=0, stop=self.num_patches + 1, step=1), axis=0
        )
        projected_patches = self.projection(patch)

        # Get the batch size from the input feature shape
        batch_size = tf.shape(patch)[0]

        # Repeat the CLS token for each item in the batch
        cls_tokens = tf.repeat(self.cls_token, batch_size, axis=0)

        # Concatenate CLS token with projected patches
        encoded = tf.concat([cls_tokens, projected_patches], axis=1)

        encoded = encoded + self.position_embedding(positions)

        encoded = self.dropout(encoded)

        return encoded

    def get_config(self):
        config = super().get_config()
        config.update({"num_patches": self.num_patches})
        return config

# %%
class FeedForward(tf.keras.Model):

    def __init__(self, dim, hidden_dim):
        super().__init__()
        self.net = tf.keras.Sequential([tf.keras.layers.Dense(hidden_dim, activation=keras.activations.gelu),
                                        tf.keras.layers.Dense(dim)])

    def call(self, x):
        return self.net(x)

# %%
class ViT(keras.Model):
    def __init__(self, image_size, patch_size, dim, depth, heads, mlp_dim,
                pool='cls', dim_head=64, dropout=0.0, emb_dropout=0.0):
        super().__init__()
    
        self.image_size = image_size
        self.patch_size = patch_size
        self.dim = dim
        self.depth = depth
        self.heads = heads
        self.mlp_dim = mlp_dim
        self.pool = pool
        self.dim_head = dim_head
        self.dropout = dropout
        self.emb_dropout = emb_dropout
        
        assert image_size % patch_size == 0, 'image dimensions must be divisible by the patch size'
        self.num_patches = (image_size // patch_size) ** 2
        
        self.patch_layer = Patches(patch_size)
        
        self.patch_encoder = PatchEncoder(self.num_patches, dim, emb_dropout)
        
        self.transformer_blocks = [self.create_transformer_block() for _ in range(depth)]
        
        self.layer_norm = layers.LayerNormalization(epsilon=1e-6)


    def create_transformer_block(self):
        return {
            'layer_norm1': layers.LayerNormalization(epsilon=1e-6),
            'attention': layers.MultiHeadAttention(num_heads=self.heads, key_dim=self.dim_head, dropout=self.dropout),
            'layer_norm2': layers.LayerNormalization(epsilon=1e-6),
            'mlp': FeedForward(self.dim, self.mlp_dim)
        }

    def call(self, inputs):
        x = self.patch_layer(inputs)
        x = self.patch_encoder(x)
        
        # Compute multiple layers of the Transformer block.
        for block in self.transformer_blocks:
            # Layer normalization 1.
            x1 = block['layer_norm1'](x)
            # Create a multi-head attention layer.
            attention_output = block['attention'](x1, x1)
            # Skip connection 1.
            x2 = layers.Add()([attention_output, x])
            # Layer normalization 2.
            x3 = block['layer_norm2'](x2)
            # MLP.
            x3 = block['mlp'](x3)
            # Skip connection 2.
            x = layers.Add()([x3, x2])
        
        representation = self.layer_norm(x)
        
        if self.pool == 'mean':
            return tf.reduce_mean(representation, axis=1)
        else:
            return representation[:, 0]

# %%
def create_model1(imgs_shape):
    print(f"Input image shape: {imgs_shape}")

    vit_input = Input(shape=imgs_shape)
    print(f"ViT input shape: {vit_input.shape}")

    vit_model = ViT(
        image_size = imgs_shape[0],
        patch_size = imgs_shape[0],
        dim = 64,
        depth = 2,
        heads = 4,
        mlp_dim = 128,
        dropout = 0.1,
        emb_dropout = 0.1
    )

    vit_output = vit_model(vit_input)
    print(f"ViT output shape: {vit_output.shape}")

    vit_output = Dense(64, activation='relu', name='dense_1')(vit_output)
    print(f"After first Dense layer: {vit_output.shape}")

    vit_output = Dense(32, activation='relu', name='dense_2')(vit_output)
    print(f"After second Dense layer: {vit_output.shape}")

    vit_output = Dense(16, activation='relu', name='dense_3')(vit_output)
    print(f"After third Dense layer: {vit_output.shape}")

    final_output = Dense(1, activation='linear', name='output')(vit_output)
    print(f"Final output shape: {final_output.shape}")

    # Create the hybrid model
    model1 = Model(inputs=vit_input, outputs=final_output)

    # Print model summary
    model1.summary()

    return model1

# %%
# Test the model creation
test_shape = (20, 20, 3)  # Example input shape
model = create_model1(test_shape)
# Out:
# Input image shape: (20, 20, 3)
# ViT input shape: (None, 20, 20, 3)
# ViT output shape: (None, 64)
# After first Dense layer: (None, 64)
# After second Dense layer: (None, 32)
# After third Dense layer: (None, 16)
# Final output shape: (None, 1)
# Model: "functional_89"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_70 (InputLayer)     │ (None, 20, 20, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vi_t_27 (ViT)                   │ (None, 64)             │       243,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 250,369 (978.00 KB)
#  Trainable params: 250,369 (978.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Create some dummy data
import numpy as np
dummy_input = np.random.random((1, 20, 20, 3))

# Try to predict
try:
    prediction = model.predict(dummy_input)
    print(f"Prediction shape: {prediction.shape}")
    print(f"Prediction: {prediction}")
except Exception as e:
    print(f"Error during prediction: {e}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# Prediction shape: (1, 1)
# Prediction: [[-0.46044815]]

# %%
# ViT same patch size as image size

def create_model1(imgs_shape):
    vit_input = Input(shape=imgs_shape)

    vit_model = ViT(
        image_size = imgs_shape[0],
        patch_size = imgs_shape[0],
        dim = 64,
        depth = 2,
        heads = 4,
        mlp_dim = 128,
        dropout = 0.1,
        emb_dropout = 0.1
    )

    vit_output = vit_model(vit_input)

    vit_output = Dense(64, activation='relu')(vit_output)
    vit_output = Dense(32, activation='relu')(vit_output)
    vit_output = Dense(16, activation='relu')(vit_output)
    final_output = Dense(1, activation='linear')(vit_output)  # Output layer for regression

    # Create the hybrid model
    model1 = Model(inputs=vit_input, outputs=final_output)

    return model1

# %%
# ViT with patch size as divisor of image size

def find_divisors(n):
    divisors = []
    for i in range(1, int(n**0.5) + 1):
        if n % i == 0:
            divisors.append(i)
            if i != n // i:  # Check to include both divisors if they are not the same
                divisors.append(n // i)
    divisors.sort()
    return divisors

def create_model2(imgs_shape):
    divisors = find_divisors(imgs_shape[0])
    
    vit_input = Input(shape=imgs_shape)

    vit_model = ViT(
        image_size = imgs_shape[0],
        patch_size = divisors[-2],
        dim = 64,
        depth = 2,
        heads = 4,
        mlp_dim = 128,
        dropout = 0.1,
        emb_dropout = 0.1
    )

    # Wrap the ViT model call in a Lambda layer
    vit_output = vit_model(vit_input)

    vit_output = Dense(64, activation='relu')(vit_output)
    vit_output = Dense(32, activation='relu')(vit_output)
    vit_output = Dense(16, activation='relu')(vit_output)
    final_output = Dense(1, activation='linear')(vit_output)  # Output layer for regression

    # Create the hybrid model
    model2 = Model(inputs=vit_input, outputs=final_output)

    return model2

# %%
def create_model3(imgs_shape):
    divisors = find_divisors(imgs_shape[0])
    
    vit_input = Input(shape=imgs_shape)

    vit_model = ViT(
        image_size = imgs_shape[0],
        patch_size = divisors[-3],
        dim = 64,
        depth = 2,
        heads = 4,
        mlp_dim = 128,
        dropout = 0.1,
        emb_dropout = 0.1
    )

    # Wrap the ViT model call in a Lambda layer
    vit_output = vit_model(vit_input)

    vit_output = Dense(64, activation='relu')(vit_output)
    vit_output = Dense(32, activation='relu')(vit_output)
    vit_output = Dense(16, activation='relu')(vit_output)
    final_output = Dense(1, activation='linear')(vit_output)  # Output layer for regression

    # Create the hybrid model
    model2 = Model(inputs=vit_input, outputs=final_output)

    return model2

# %% [markdown]
# METRICS

# %%
import tensorflow.keras.backend as K

def r_square(y_true, y_pred):
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    r2 = 1 - SS_res / (SS_tot + K.epsilon())
    return r2

METRICS = [
    tf.keras.metrics.MeanSquaredError(name = 'mse'),
    tf.keras.metrics.MeanAbsoluteError(name = 'mae'),
    tf.keras.metrics.RootMeanSquaredError(name = 'rmse'),
    r_square,
]

# %% [markdown]
# COMPILE AND FIT

# %%
from tensorflow.keras.callbacks import EarlyStopping

def compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test,dataset_name, model_name, batch_size=32, epochs=200, lr=1e-3):

    opt = Adam(learning_rate=lr)

    # Define the early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',  # Monitor the validation loss
        min_delta=0.001,     # Minimum change in the monitored quantity to qualify as an improvement
        patience=20,          # Number of epochs with no improvement after which training will be stopped
        verbose=1,           # Print messages when the callback takes an action
        mode='min',           # Training will stop when the quantity monitored has stopped decreasing
        restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
    )

    
    model.compile(
        loss="mse",
        optimizer=opt,
        metrics=METRICS
    )

    model_history = model.fit(
        x=X_train_img, y=y_train,
        validation_data=(X_val_img, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    os.makedirs(f"models/{dataset_name}/{model_name}", exist_ok=True)

    plt.figure()  # Start a new figure
    plt.plot(model_history.history['loss'], color = 'red', label = 'loss')
    plt.plot(model_history.history['val_loss'], color = 'green', label = 'val loss')
    plt.legend(loc = 'upper right')
    plt.savefig(f"models/{dataset_name}/{model_name}/loss_plot.png")

    plt.figure()  # Start a new figure
    plt.plot(model_history.history['mse'], color = 'red', label = 'mse')
    plt.plot(model_history.history['val_mse'], color = 'green', label = 'val mse')
    plt.legend(loc = 'upper right')
    plt.savefig(f"models/{dataset_name}/{model_name}/mse_plot.png")

    # Save the model
    os.makedirs(f"models/{dataset_name}/{model_name}", exist_ok=True)
    model.save(f"models/{dataset_name}/{model_name}/model_{dataset_name}.keras")

    # Evaluate the model on the training set
    train_scores = model.evaluate(X_train_img, y_train)

    # Evaluate the model on the validation set
    val_scores = model.evaluate(X_val_img, y_val)

    # Evaluate the model on the test set
    score_test = model.evaluate(X_test_img, y_test)

    # Save training, validation, and test scores
    metrics = {
        'train_loss': train_scores[0],
        'train_mse': train_scores[1],
        'train_mae': train_scores[2],
        'train_rmse': train_scores[3],
        'train_r2': train_scores[4],
        'val_loss': val_scores[0],
        'val_mse': val_scores[1],
        'val_mae': val_scores[2],
        'val_rmse': val_scores[3],
        'val_r2': val_scores[4],
        'test_loss': score_test[0],
        'test_mse': score_test[1],
        'test_mae': score_test[2],
        'test_rmse': score_test[3],
        'test_r2': score_test[4]
    }

    # Save metrics to a file
    os.makedirs(f'{results_path}/{model_name}', exist_ok=True)
    with open(f'{results_path}/{model_name}/{dataset_name}_metrics.txt', 'w') as f:
        for key, value in metrics.items():
            f.write(f'{key}: {value}\n')

    return metrics

# %%
def safe_compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test,dataset_name, model_name, batch_size=32, epochs=200, lr=1e-3):
    try:
        metrics = compile_and_fit(model, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test,dataset_name, model_name, batch_size, epochs, lr)
        return metrics
    except Exception as e:
        print(f"Failed to compile and fit {model_name}: {str(e)}")
        return None

# %% [markdown]
# rmse: 0.9078
# - Patch size de 3: 0.8711, un patch grande para imagenes pequenas parece funcionar bien.
# - Mas capas finales: 0.8868 No mejora

# %% [markdown]
# TEST

# %%
#Select the model and the parameters
problem_type = "regression"
#image_model = REFINED(problem= problem_type,hcIterations=5)
image_model = TINTO(problem= problem_type, blur=True)
#image_model = IGTD(problem= problem_type)
#image_model = BarGraph(problem= problem_type)
#image_model = DistanceMatrix(problem= problem_type)
#image_model = Combination(problem= problem_type)
#image_model = SuperTML(problem= problem_type)

#Define the dataset path and the folder where the images will be saved
images_folder = f"../HyNNImages/Regression/{dataset_name}/images_{dataset_name}_IGTD"

# %%
#Select the model and the parameters
problem_type = "regression"
image_model = TINTO(problem= problem_type, blur=True)

#Define the dataset path and the folder where the images will be saved
images_folder = f"../HyNNImages/Regression/{dataset_name}/images_{dataset_name}_TINTO"

# %%
X_train_num, X_val_num, X_test_num, X_train_img, X_val_img, X_test_img, y_train, y_val, y_test, imgs_shape, attributes = load_and_preprocess_data(images_folder, image_model, problem_type)
# Out:
# The images are already generated
# ../HyNNImages/Regression/california_housing/images_california_housing_TINTO\regression.csv
# Images shape:  (20, 20, 3)
# Attributres:  8
# Image size (pixels): 20

# %%
imgs_shape
# Out:
# (20, 20, 3)

# %%
model1 = create_model1(imgs_shape)
model2 = create_model2(imgs_shape)
model3 = create_model3(imgs_shape)

# %%
# Example usage with two models
model1_metrics = safe_compile_and_fit(model1, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_model1")
model2_metrics = safe_compile_and_fit(model2, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_Model2")
model3_metrics = safe_compile_and_fit(model3, X_train_num, X_train_img, y_train, X_val_num, X_val_img, y_val, X_test_num, X_test_img, y_test, dataset_name, "TINTO_Model3")

# Print comparison of metrics only for models that ran successfully
if model1_metrics:
    print("Model 1 Metrics:", model1_metrics)
if model2_metrics:
    print("Model 2 Metrics:", model2_metrics)
if model3_metrics:
    print("Model 3 Metrics:", model3_metrics)
# Out:
# Epoch 1/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 1.8872 - mae: 1.0454 - mse: 1.8872 - r_square: -0.4262 - rmse: 1.3436 - val_loss: 1.3741 - val_mae: 0.9377 - val_mse: 1.3741 - val_r_square: -0.0444 - val_rmse: 1.1722
# Epoch 2/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3557 - mae: 0.9185 - mse: 1.3557 - r_square: -0.0375 - rmse: 1.1642 - val_loss: 1.3724 - val_mae: 0.9342 - val_mse: 1.3724 - val_r_square: -0.0422 - val_rmse: 1.1715
# Epoch 3/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3551 - mae: 0.9184 - mse: 1.3551 - r_square: -0.0368 - rmse: 1.1640 - val_loss: 1.3706 - val_mae: 0.9285 - val_mse: 1.3706 - val_r_square: -0.0393 - val_rmse: 1.1707
# Epoch 4/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3541 - mae: 0.9180 - mse: 1.3541 - r_square: -0.0360 - rmse: 1.1636 - val_loss: 1.3718 - val_mae: 0.9327 - val_mse: 1.3718 - val_r_square: -0.0414 - val_rmse: 1.1712
# Epoch 5/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3535 - mae: 0.9178 - mse: 1.3535 - r_square: -0.0354 - rmse: 1.1633 - val_loss: 1.3718 - val_mae: 0.9328 - val_mse: 1.3718 - val_r_square: -0.0414 - val_rmse: 1.1712
# Epoch 6/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3558 - mae: 0.9186 - mse: 1.3558 - r_square: -0.0374 - rmse: 1.1643 - val_loss: 1.3721 - val_mae: 0.9334 - val_mse: 1.3721 - val_r_square: -0.0418 - val_rmse: 1.1714
# Epoch 7/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1.3537 - mae: 0.9181 - mse: 1.3537 - r_square: -0.0353 - rmse: 1.1634 - val_loss: 1.3725 - val_mae: 0.9344 - val_mse: 1.3725 - val_r_square: -0.0424 - val_rmse: 1.1715
# Epoch 8/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.3535 - mae: 0.9180 - mse: 1.3535 - r_square: -0.0351 - rmse: 1.1633 - val_loss: 1.3726 - val_mae: 0.9345 - val_mse: 1.3726 - val_r_square: -0.0425 - val_rmse: 1.1716
# Epoch 9/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3533 - mae: 0.9180 - mse: 1.3533 - r_square: -0.0350 - rmse: 1.1632 - val_loss: 1.3729 - val_mae: 0.9352 - val_mse: 1.3729 - val_r_square: -0.0429 - val_rmse: 1.1717
# Epoch 10/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3532 - mae: 0.9180 - mse: 1.3532 - r_square: -0.0348 - rmse: 1.1632 - val_loss: 1.3731 - val_mae: 0.9357 - val_mse: 1.3731 - val_r_square: -0.0432 - val_rmse: 1.1718
# Epoch 11/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3531 - mae: 0.9179 - mse: 1.3531 - r_square: -0.0347 - rmse: 1.1631 - val_loss: 1.3730 - val_mae: 0.9355 - val_mse: 1.3730 - val_r_square: -0.0431 - val_rmse: 1.1718
# Epoch 12/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3530 - mae: 0.9180 - mse: 1.3530 - r_square: -0.0346 - rmse: 1.1631 - val_loss: 1.3734 - val_mae: 0.9363 - val_mse: 1.3734 - val_r_square: -0.0436 - val_rmse: 1.1719
# Epoch 13/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.3530 - mae: 0.9181 - mse: 1.3530 - r_square: -0.0347 - rmse: 1.1631 - val_loss: 1.3736 - val_mae: 0.9368 - val_mse: 1.3736 - val_r_square: -0.0439 - val_rmse: 1.1720
# Epoch 14/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3527 - mae: 0.9179 - mse: 1.3527 - r_square: -0.0343 - rmse: 1.1630 - val_loss: 1.3736 - val_mae: 0.9366 - val_mse: 1.3736 - val_r_square: -0.0438 - val_rmse: 1.1720
# Epoch 15/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3530 - mae: 0.9180 - mse: 1.3530 - r_square: -0.0345 - rmse: 1.1631 - val_loss: 1.3740 - val_mae: 0.9374 - val_mse: 1.3740 - val_r_square: -0.0443 - val_rmse: 1.1722
# Epoch 16/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3526 - mae: 0.9180 - mse: 1.3526 - r_square: -0.0342 - rmse: 1.1629 - val_loss: 1.3743 - val_mae: 0.9380 - val_mse: 1.3743 - val_r_square: -0.0447 - val_rmse: 1.1723
# Epoch 17/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3525 - mae: 0.9180 - mse: 1.3525 - r_square: -0.0340 - rmse: 1.1629 - val_loss: 1.3743 - val_mae: 0.9380 - val_mse: 1.3743 - val_r_square: -0.0447 - val_rmse: 1.1723
# Epoch 18/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3524 - mae: 0.9179 - mse: 1.3524 - r_square: -0.0340 - rmse: 1.1628 - val_loss: 1.3743 - val_mae: 0.9381 - val_mse: 1.3743 - val_r_square: -0.0448 - val_rmse: 1.1723
# Epoch 19/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3524 - mae: 0.9179 - mse: 1.3524 - r_square: -0.0340 - rmse: 1.1628 - val_loss: 1.3740 - val_mae: 0.9374 - val_mse: 1.3740 - val_r_square: -0.0443 - val_rmse: 1.1722
# Epoch 20/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.3526 - mae: 0.9182 - mse: 1.3526 - r_square: -0.0341 - rmse: 1.1629 - val_loss: 1.3743 - val_mae: 0.9381 - val_mse: 1.3743 - val_r_square: -0.0448 - val_rmse: 1.1723
# Epoch 21/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3524 - mae: 0.9180 - mse: 1.3524 - r_square: -0.0340 - rmse: 1.1628 - val_loss: 1.3751 - val_mae: 0.9393 - val_mse: 1.3751 - val_r_square: -0.0457 - val_rmse: 1.1726
# Epoch 22/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3523 - mae: 0.9180 - mse: 1.3523 - r_square: -0.0338 - rmse: 1.1628 - val_loss: 1.3753 - val_mae: 0.9398 - val_mse: 1.3753 - val_r_square: -0.0460 - val_rmse: 1.1727
# Epoch 23/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3519 - mae: 0.9179 - mse: 1.3519 - r_square: -0.0337 - rmse: 1.1626 - val_loss: 1.3750 - val_mae: 0.9394 - val_mse: 1.3750 - val_r_square: -0.0457 - val_rmse: 1.1726
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.3494 - mae: 0.9227 - mse: 1.3494 - r_square: -0.0403 - rmse: 1.1613
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.
200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3539 - mae: 0.9181 - mse: 1.3539 - r_square: -0.0355 - rmse: 1.1635 - val_loss: 1.3719 - val_mae: 0.9330 - val_mse: 1.3719 - val_r_square: -0.0416 - val_rmse: 1.1713
# Epoch 14/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3536 - mae: 0.9181 - mse: 1.3536 - r_square: -0.0353 - rmse: 1.1634 - val_loss: 1.3725 - val_mae: 0.9344 - val_mse: 1.3725 - val_r_square: -0.0424 - val_rmse: 1.1715
# Epoch 15/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3536 - mae: 0.9182 - mse: 1.3536 - r_square: -0.0353 - rmse: 1.1634 - val_loss: 1.3723 - val_mae: 0.9340 - val_mse: 1.3723 - val_r_square: -0.0422 - val_rmse: 1.1715
# Epoch 16/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3534 - mae: 0.9181 - mse: 1.3534 - r_square: -0.0351 - rmse: 1.1633 - val_loss: 1.3726 - val_mae: 0.9347 - val_mse: 1.3726 - val_r_square: -0.0425 - val_rmse: 1.1716
# Epoch 17/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3534 - mae: 0.9180 - mse: 1.3534 - r_square: -0.0350 - rmse: 1.1633 - val_loss: 1.3727 - val_mae: 0.9348 - val_mse: 1.3727 - val_r_square: -0.0426 - val_rmse: 1.1716
# Epoch 18/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3533 - mae: 0.9180 - mse: 1.3533 - r_square: -0.0349 - rmse: 1.1632 - val_loss: 1.3703 - val_mae: 0.9266 - val_mse: 1.3703 - val_r_square: -0.0386 - val_rmse: 1.1706
# Epoch 19/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3548 - mae: 0.9185 - mse: 1.3548 - r_square: -0.0367 - rmse: 1.1638 - val_loss: 1.3730 - val_mae: 0.9355 - val_mse: 1.3730 - val_r_square: -0.0431 - val_rmse: 1.1717
# Epoch 20/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3530 - mae: 0.9180 - mse: 1.3530 - r_square: -0.0346 - rmse: 1.1631 - val_loss: 1.3733 - val_mae: 0.9361 - val_mse: 1.3733 - val_r_square: -0.0434 - val_rmse: 1.1719
# Epoch 21/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3529 - mae: 0.9180 - mse: 1.3529 - r_square: -0.0344 - rmse: 1.1630 - val_loss: 1.3735 - val_mae: 0.9365 - val_mse: 1.3735 - val_r_square: -0.0437 - val_rmse: 1.1720
# Epoch 22/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3527 - mae: 0.9179 - mse: 1.3527 - r_square: -0.0343 - rmse: 1.1630 - val_loss: 1.3771 - val_mae: 0.9430 - val_mse: 1.3771 - val_r_square: -0.0482 - val_rmse: 1.1735
# Epoch 23/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3536 - mae: 0.9184 - mse: 1.3536 - r_square: -0.0354 - rmse: 1.1634 - val_loss: 1.3735 - val_mae: 0.9365 - val_mse: 1.3735 - val_r_square: -0.0437 - val_rmse: 1.1720
# Epoch 24/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3526 - mae: 0.9179 - mse: 1.3526 - r_square: -0.0342 - rmse: 1.1629 - val_loss: 1.3746 - val_mae: 0.9386 - val_mse: 1.3746 - val_r_square: -0.0451 - val_rmse: 1.1724
# Epoch 25/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3526 - mae: 0.9180 - mse: 1.3526 - r_square: -0.0341 - rmse: 1.1629 - val_loss: 1.3746 - val_mae: 0.9386 - val_mse: 1.3746 - val_r_square: -0.0451 - val_rmse: 1.1724
# Epoch 26/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3525 - mae: 0.9180 - mse: 1.3525 - r_square: -0.0340 - rmse: 1.1629 - val_loss: 1.3748 - val_mae: 0.9391 - val_mse: 1.3748 - val_r_square: -0.0454 - val_rmse: 1.1725
# Epoch 27/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3524 - mae: 0.9180 - mse: 1.3524 - r_square: -0.0339 - rmse: 1.1628 - val_loss: 1.3747 - val_mae: 0.9391 - val_mse: 1.3747 - val_r_square: -0.0453 - val_rmse: 1.1725
# Epoch 28/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3521 - mae: 0.9179 - mse: 1.3521 - r_square: -0.0337 - rmse: 1.1627 - val_loss: 1.3744 - val_mae: 0.9390 - val_mse: 1.3744 - val_r_square: -0.0451 - val_rmse: 1.1723
# Epoch 29/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3518 - mae: 0.9178 - mse: 1.3518 - r_square: -0.0335 - rmse: 1.1626 - val_loss: 1.3704 - val_mae: 0.9340 - val_mse: 1.3704 - val_r_square: -0.0407 - val_rmse: 1.1706
# Epoch 30/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1.3478 - mae: 0.9164 - mse: 1.3478 - r_square: -0.0310 - rmse: 1.1608 - val_loss: 1.3468 - val_mae: 0.9345 - val_mse: 1.3468 - val_r_square: -0.0238 - val_rmse: 1.1605
# Epoch 31/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3290 - mae: 0.9117 - mse: 1.3290 - r_square: -0.0171 - rmse: 1.1527 - val_loss: 1.3374 - val_mae: 0.9321 - val_mse: 1.3374 - val_r_square: -0.0165 - val_rmse: 1.1565
# Epoch 32/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.3197 - mae: 0.9087 - mse: 1.3197 - r_square: -0.0111 - rmse: 1.1487 - val_loss: 1.3323 - val_mae: 0.9259 - val_mse: 1.3323 - val_r_square: -0.0114 - val_rmse: 1.1543
# Epoch 33/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3192 - mae: 0.9081 - mse: 1.3192 - r_square: -0.0106 - rmse: 1.1485 - val_loss: 1.3283 - val_mae: 0.9162 - val_mse: 1.3283 - val_r_square: -0.0060 - val_rmse: 1.1525
# Epoch 34/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3184 - mae: 0.9080 - mse: 1.3184 - r_square: -0.0101 - rmse: 1.1481 - val_loss: 1.3311 - val_mae: 0.9206 - val_mse: 1.3311 - val_r_square: -0.0092 - val_rmse: 1.1537
# Epoch 35/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3180 - mae: 0.9070 - mse: 1.3180 - r_square: -0.0095 - rmse: 1.1479 - val_loss: 1.3301 - val_mae: 0.9242 - val_mse: 1.3301 - val_r_square: -0.0094 - val_rmse: 1.1533
# Epoch 36/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3177 - mae: 0.9076 - mse: 1.3177 - r_square: -0.0097 - rmse: 1.1478 - val_loss: 1.3305 - val_mae: 0.9236 - val_mse: 1.3305 - val_r_square: -0.0095 - val_rmse: 1.1535
# Epoch 37/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3148 - mae: 0.9063 - mse: 1.3148 - r_square: -0.0079 - rmse: 1.1466 - val_loss: 1.3284 - val_mae: 0.9220 - val_mse: 1.3284 - val_r_square: -0.0076 - val_rmse: 1.1526
# Epoch 38/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3123 - mae: 0.9053 - mse: 1.3123 - r_square: -0.0055 - rmse: 1.1455 - val_loss: 1.3287 - val_mae: 0.9204 - val_mse: 1.3287 - val_r_square: -0.0074 - val_rmse: 1.1527
# Epoch 39/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3165 - mae: 0.9074 - mse: 1.3165 - r_square: -0.0083 - rmse: 1.1473 - val_loss: 1.3256 - val_mae: 0.9200 - val_mse: 1.3256 - val_r_square: -0.0052 - val_rmse: 1.1513
# Epoch 40/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3171 - mae: 0.9069 - mse: 1.3171 - r_square: -0.0095 - rmse: 1.1476 - val_loss: 1.3357 - val_mae: 0.9361 - val_mse: 1.3357 - val_r_square: -0.0167 - val_rmse: 1.1557
# Epoch 41/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.3141 - mae: 0.9072 - mse: 1.3141 - r_square: -0.0067 - rmse: 1.1463 - val_loss: 1.3292 - val_mae: 0.9248 - val_mse: 1.3292 - val_r_square: -0.0090 - val_rmse: 1.1529
# Epoch 42/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.3117 - mae: 0.9058 - mse: 1.3117 - r_square: -0.0053 - rmse: 1.1452 - val_loss: 1.3187 - val_mae: 0.9163 - val_mse: 1.3187 - val_r_square: 3.3009e-04 - val_rmse: 1.1483
# Epoch 43/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.3114 - mae: 0.9030 - mse: 1.3114 - r_square: -0.0043 - rmse: 1.1451 - val_loss: 1.3294 - val_mae: 0.9286 - val_mse: 1.3294 - val_r_square: -0.0101 - val_rmse: 1.1530
# Epoch 44/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 1.3105 - mae: 0.9043 - mse: 1.3105 - r_square: -0.0045 - rmse: 1.1447 - val_loss: 1.3163 - val_mae: 0.9190 - val_mse: 1.3163 - val_r_square: 0.0010 - val_rmse: 1.1473
# Epoch 45/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3055 - mae: 0.9031 - mse: 1.3055 - r_square: -3.7142e-04 - rmse: 1.1425 - val_loss: 1.2755 - val_mae: 0.9002 - val_mse: 1.2755 - val_r_square: 0.0323 - val_rmse: 1.1294
# Epoch 46/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.2816 - mae: 0.8926 - mse: 1.2816 - r_square: 0.0152 - rmse: 1.1319 - val_loss: 1.2359 - val_mae: 0.9206 - val_mse: 1.2359 - val_r_square: 0.0498 - val_rmse: 1.1117
# Epoch 47/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.1378 - mae: 0.8298 - mse: 1.1378 - r_square: 0.1219 - rmse: 1.0660 - val_loss: 0.9515 - val_mae: 0.7910 - val_mse: 0.9515 - val_r_square: 0.2526 - val_rmse: 0.9755
# Epoch 48/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.9400 - mae: 0.7414 - mse: 0.9400 - r_square: 0.2715 - rmse: 0.9693 - val_loss: 1.3409 - val_mae: 0.9239 - val_mse: 1.3409 - val_r_square: -0.0184 - val_rmse: 1.1580
# Epoch 49/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.3331 - mae: 0.9107 - mse: 1.3331 - r_square: -0.0201 - rmse: 1.1545 - val_loss: 1.2743 - val_mae: 0.8917 - val_mse: 1.2743 - val_r_square: 0.0353 - val_rmse: 1.1288
# Epoch 50/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.2673 - mae: 0.8847 - mse: 1.2673 - r_square: 0.0287 - rmse: 1.1254 - val_loss: 1.0186 - val_mae: 0.8510 - val_mse: 1.0186 - val_r_square: 0.2086 - val_rmse: 1.0092
# Epoch 51/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.9899 - mae: 0.7668 - mse: 0.9899 - r_square: 0.2340 - rmse: 0.9944 - val_loss: 0.6925 - val_mae: 0.6565 - val_mse: 0.6925 - val_r_square: 0.4643 - val_rmse: 0.8322
# Epoch 52/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0
200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5450 - mae: 0.5378 - mse: 0.5450 - r_square: 0.5773 - rmse: 0.7382 - val_loss: 0.5343 - val_mae: 0.5171 - val_mse: 0.5343 - val_r_square: 0.5916 - val_rmse: 0.7310
# Epoch 118/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.5405 - mae: 0.5330 - mse: 0.5405 - r_square: 0.5792 - rmse: 0.7351 - val_loss: 0.5608 - val_mae: 0.5252 - val_mse: 0.5608 - val_r_square: 0.5732 - val_rmse: 0.7489
# Epoch 119/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5352 - mae: 0.5312 - mse: 0.5352 - r_square: 0.5846 - rmse: 0.7315 - val_loss: 0.5418 - val_mae: 0.5436 - val_mse: 0.5418 - val_r_square: 0.5861 - val_rmse: 0.7361
# Epoch 120/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5357 - mae: 0.5309 - mse: 0.5357 - r_square: 0.5838 - rmse: 0.7318 - val_loss: 0.5384 - val_mae: 0.5129 - val_mse: 0.5384 - val_r_square: 0.5883 - val_rmse: 0.7338
# Epoch 121/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.5370 - mae: 0.5316 - mse: 0.5370 - r_square: 0.5833 - rmse: 0.7327 - val_loss: 0.5434 - val_mae: 0.5152 - val_mse: 0.5434 - val_r_square: 0.5851 - val_rmse: 0.7372
# Epoch 122/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5412 - mae: 0.5319 - mse: 0.5412 - r_square: 0.5783 - rmse: 0.7356 - val_loss: 0.5468 - val_mae: 0.5166 - val_mse: 0.5468 - val_r_square: 0.5825 - val_rmse: 0.7395
# Epoch 123/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5334 - mae: 0.5321 - mse: 0.5334 - r_square: 0.5838 - rmse: 0.7303 - val_loss: 0.5355 - val_mae: 0.5370 - val_mse: 0.5355 - val_r_square: 0.5900 - val_rmse: 0.7318
# Epoch 123: early stopping
# Restoring model weights from the end of the best epoch: 103.
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5010 - mae: 0.5034 - mse: 0.5010 - r_square: 0.6089 - rmse: 0.7076
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5056 - mae: 0.5044 - mse: 0.5056 - r_square: 0.6142 - rmse: 0.7106
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4810 - mae: 0.4921 - mse: 0.4810 - r_square: 0.6134 - rmse: 0.6935
# Epoch 1/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1.5274 - mae: 0.7366 - mse: 0.9949 - r_square: -0.1634 - rmse: 0.9945 - val_loss: 1.3713 - val_mae: 0.9194 - val_mse: 1.3713 - val_r_square: -0.0372 - val_rmse: 1.1710
# Epoch 2/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3617 - mae: 0.9204 - mse: 1.3617 - r_square: -0.0431 - rmse: 1.1668 - val_loss: 1.3708 - val_mae: 0.9344 - val_mse: 1.3708 - val_r_square: -0.0411 - val_rmse: 1.1708
# Epoch 3/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3485 - mae: 0.9157 - mse: 1.3485 - r_square: -0.0328 - rmse: 1.1611 - val_loss: 1.3413 - val_mae: 0.9343 - val_mse: 1.3413 - val_r_square: -0.0208 - val_rmse: 1.1581
# Epoch 4/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3365 - mae: 0.9103 - mse: 1.3365 - r_square: -0.0237 - rmse: 1.1560 - val_loss: 1.3474 - val_mae: 0.9321 - val_mse: 1.3474 - val_r_square: -0.0239 - val_rmse: 1.1608
# Epoch 5/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3310 - mae: 0.9111 - mse: 1.3310 - r_square: -0.0204 - rmse: 1.1536 - val_loss: 1.3415 - val_mae: 0.9300 - val_mse: 1.3415 - val_r_square: -0.0189 - val_rmse: 1.1582
# Epoch 6/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3270 - mae: 0.9092 - mse: 1.3270 - r_square: -0.0173 - rmse: 1.1519 - val_loss: 1.3407 - val_mae: 0.9312 - val_mse: 1.3407 - val_r_square: -0.0190 - val_rmse: 1.1579
# Epoch 7/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3313 - mae: 0.9119 - mse: 1.3313 - r_square: -0.0206 - rmse: 1.1537 - val_loss: 1.3407 - val_mae: 0.9318 - val_mse: 1.3407 - val_r_square: -0.0190 - val_rmse: 1.1579
# Epoch 8/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3275 - mae: 0.9102 - mse: 1.3275 - r_square: -0.0176 - rmse: 1.1521 - val_loss: 1.3404 - val_mae: 0.9313 - val_mse: 1.3404 - val_r_square: -0.0184 - val_rmse: 1.1577
# Epoch 9/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3261 - mae: 0.9097 - mse: 1.3261 - r_square: -0.0161 - rmse: 1.1514 - val_loss: 1.3372 - val_mae: 0.9304 - val_mse: 1.3372 - val_r_square: -0.0159 - val_rmse: 1.1564
# Epoch 10/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3257 - mae: 0.9112 - mse: 1.3257 - r_square: -0.0164 - rmse: 1.1513 - val_loss: 1.3422 - val_mae: 0.9340 - val_mse: 1.3422 - val_r_square: -0.0204 - val_rmse: 1.1585
# Epoch 11/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3239 - mae: 0.9098 - mse: 1.3239 - r_square: -0.0152 - rmse: 1.1505 - val_loss: 1.3381 - val_mae: 0.9308 - val_mse: 1.3381 - val_r_square: -0.0167 - val_rmse: 1.1568
# Epoch 12/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3210 - mae: 0.9104 - mse: 1.3210 - r_square: -0.0132 - rmse: 1.1493 - val_loss: 1.3355 - val_mae: 0.9283 - val_mse: 1.3355 - val_r_square: -0.0142 - val_rmse: 1.1556
# Epoch 13/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3203 - mae: 0.9093 - mse: 1.3203 - r_square: -0.0125 - rmse: 1.1490 - val_loss: 1.3344 - val_mae: 0.9304 - val_mse: 1.3344 - val_r_square: -0.0141 - val_rmse: 1.1552
# Epoch 14/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3179 - mae: 0.9087 - mse: 1.3179 - r_square: -0.0106 - rmse: 1.1479 - val_loss: 1.3319 - val_mae: 0.9281 - val_mse: 1.3319 - val_r_square: -0.0118 - val_rmse: 1.1541
# Epoch 15/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3176 - mae: 0.9084 - mse: 1.3176 - r_square: -0.0104 - rmse: 1.1478 - val_loss: 1.3249 - val_mae: 0.9205 - val_mse: 1.3249 - val_r_square: -0.0050 - val_rmse: 1.1510
# Epoch 16/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1.3146 - mae: 0.9066 - mse: 1.3146 - r_square: -0.0081 - rmse: 1.1465 - val_loss: 1.3292 - val_mae: 0.9227 - val_mse: 1.3292 - val_r_square: -0.0085 - val_rmse: 1.1529
# Epoch 17/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.3194 - mae: 0.9095 - mse: 1.3194 - r_square: -0.0113 - rmse: 1.1485 - val_loss: 1.3266 - val_mae: 0.9178 - val_mse: 1.3266 - val_r_square: -0.0054 - val_rmse: 1.1518
# Epoch 18/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.3165 - mae: 0.9083 - mse: 1.3165 - r_square: -0.0088 - rmse: 1.1473 - val_loss: 1.3254 - val_mae: 0.9179 - val_mse: 1.3254 - val_r_square: -0.0046 - val_rmse: 1.1513
# Epoch 19/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 
200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1.2971 - mae: 0.9004 - mse: 1.2971 - r_square: 0.0043 - rmse: 1.1388 - val_loss: 1.2691 - val_mae: 0.8912 - val_mse: 1.2691 - val_r_square: 0.0400 - val_rmse: 1.1266
# Epoch 32/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2709 - mae: 0.8872 - mse: 1.2709 - r_square: 0.0256 - rmse: 1.1272 - val_loss: 1.2343 - val_mae: 0.8696 - val_mse: 1.2343 - val_r_square: 0.0688 - val_rmse: 1.1110
# Epoch 33/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2487 - mae: 0.8768 - mse: 1.2487 - r_square: 0.0400 - rmse: 1.1173 - val_loss: 1.2625 - val_mae: 0.8744 - val_mse: 1.2625 - val_r_square: 0.0462 - val_rmse: 1.1236
# Epoch 34/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2381 - mae: 0.8755 - mse: 1.2381 - r_square: 0.0481 - rmse: 1.1126 - val_loss: 1.2173 - val_mae: 0.8674 - val_mse: 1.2173 - val_r_square: 0.0804 - val_rmse: 1.1033
# Epoch 35/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2286 - mae: 0.8712 - mse: 1.2286 - r_square: 0.0541 - rmse: 1.1083 - val_loss: 1.2534 - val_mae: 0.8825 - val_mse: 1.2534 - val_r_square: 0.0499 - val_rmse: 1.1195
# Epoch 36/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2455 - mae: 0.8782 - mse: 1.2455 - r_square: 0.0429 - rmse: 1.1159 - val_loss: 1.2064 - val_mae: 0.8636 - val_mse: 1.2064 - val_r_square: 0.0877 - val_rmse: 1.0984
# Epoch 37/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2251 - mae: 0.8669 - mse: 1.2251 - r_square: 0.0589 - rmse: 1.1068 - val_loss: 1.2375 - val_mae: 0.8665 - val_mse: 1.2375 - val_r_square: 0.0652 - val_rmse: 1.1124
# Epoch 38/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2438 - mae: 0.8767 - mse: 1.2438 - r_square: 0.0457 - rmse: 1.1152 - val_loss: 1.2140 - val_mae: 0.8545 - val_mse: 1.2140 - val_r_square: 0.0847 - val_rmse: 1.1018
# Epoch 39/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2198 - mae: 0.8664 - mse: 1.2198 - r_square: 0.0618 - rmse: 1.1044 - val_loss: 1.2064 - val_mae: 0.8626 - val_mse: 1.2064 - val_r_square: 0.0874 - val_rmse: 1.0984
# Epoch 40/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2201 - mae: 0.8670 - mse: 1.2201 - r_square: 0.0626 - rmse: 1.1045 - val_loss: 1.1913 - val_mae: 0.8412 - val_mse: 1.1913 - val_r_square: 0.1029 - val_rmse: 1.0914
# Epoch 41/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2050 - mae: 0.8593 - mse: 1.2050 - r_square: 0.0738 - rmse: 1.0976 - val_loss: 1.1864 - val_mae: 0.8451 - val_mse: 1.1864 - val_r_square: 0.1045 - val_rmse: 1.0892
# Epoch 42/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1972 - mae: 0.8560 - mse: 1.1972 - r_square: 0.0790 - rmse: 1.0941 - val_loss: 1.1706 - val_mae: 0.8407 - val_mse: 1.1706 - val_r_square: 0.1170 - val_rmse: 1.0820
# Epoch 43/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2061 - mae: 0.8619 - mse: 1.2061 - r_square: 0.0718 - rmse: 1.0981 - val_loss: 1.1689 - val_mae: 0.8362 - val_mse: 1.1689 - val_r_square: 0.1176 - val_rmse: 1.0812
# Epoch 44/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1
200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1791 - mae: 0.8463 - mse: 1.1791 - r_square: 0.0931 - rmse: 1.0858 - val_loss: 1.1570 - val_mae: 0.8212 - val_mse: 1.1570 - val_r_square: 0.1282 - val_rmse: 1.0756
# Epoch 59/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1838 - mae: 0.8487 - mse: 1.1838 - r_square: 0.0899 - rmse: 1.0879 - val_loss: 1.1521 - val_mae: 0.8233 - val_mse: 1.1521 - val_r_square: 0.1317 - val_rmse: 1.0733
# Epoch 60/200
# ...
# Epoch 98/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1181 - mae: 0.8196 - mse: 1.1181 - r_square: 0.1385 - rmse: 1.0573 - val_loss: 1.0765 - val_mae: 0.7889 - val_mse: 1.0765 - val_r_square: 0.1878 - val_rmse: 1.0375
# Epoch 99/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1377 - mae: 0.8255 - mse: 1.1377 - r_square: 0.1247 - rmse: 1.0665 - val_loss: 1.1080 - val_mae: 0.7913 - val_mse: 1.1080 - val_r_square: 0.1659 - val_rmse: 1.0526
# Epoch 100/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1240 - mae: 0.8209 - mse: 1.1240 - r_square: 0.1358 - rmse: 1.0601 - val_loss: 1.0729 - val_mae: 0.8046 - val_mse: 1.0729 - val_r_square: 0.1867 - val_rmse: 1.0358
# Epoch 101/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1204 - mae: 0.8228 - mse: 1.1204 - r_square: 0.1381 - rmse: 1.0584 - val_loss: 1.0805 - val_mae: 0.7895 - val_mse: 1.0805 - val_r_square: 0.1857 - val_rmse: 1.0395
# Epoch 102/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1130 - mae: 0.8188 - mse: 1.1130 - r_square: 0.1409 - rmse: 1.0549 - val_loss: 1.0947 - val_mae: 0.7919 - val_mse: 1.0947 - val_r_square: 0.1747 - val_rmse: 1.0463
# Epoch 103/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1175 - mae: 0.8185 - mse: 1.1175 - r_square: 0.1393 - rmse: 1.0570 - val_loss: 1.0473 - val_mae: 0.7842 - val_mse: 1.0473 - val_r_square: 0.2076 - val_rmse: 1.0234
# Epoch 104/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1131 - mae: 0.8180 - mse: 1.1131 - r_square: 0.1425 - rmse: 1.0549 - val_loss: 1.0471 - val_mae: 0.7787 - val_mse: 1.0471 - val_r_square: 0.2097 - val_rmse: 1.0233
# Epoch 105/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1107 - mae: 0.8155 - mse: 1.1107 - r_square: 0.1428 - rmse: 1.0538 - val_loss: 1.0673 - val_mae: 0.7777 - val_mse: 1.0673 - val_r_square: 0.1964 - val_rmse: 1.0331
# Epoch 106/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.1068 - mae: 0.8154 - mse: 1.1068 - r_square: 0.1472 - rmse: 1.0519 - val_loss: 1.1135 - val_mae: 0.8329 - val_mse: 1.1135 - val_r_square: 0.1458 - val_rmse: 1.0552
# Epoch 107/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 1.1048 - mae: 0.8150 - mse: 1.1048 - r_square: 0.1512 - rmse: 1.0509 - val_loss: 1.0962 - val_mae: 0.8510 - val_mse: 1.0962 - val_r_square: 0.1533 - val_rmse: 1.0470
# Epoch 108/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1
200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5805 - mae: 0.5560 - mse: 0.5805 - r_square: 0.5460 - rmse: 0.7618 - val_loss: 0.5203 - val_mae: 0.5062 - val_mse: 0.5203 - val_r_square: 0.6021 - val_rmse: 0.7213
# Epoch 148/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5573 - mae: 0.5430 - mse: 0.5573 - r_square: 0.5648 - rmse: 0.7465 - val_loss: 0.5450 - val_mae: 0.5099 - val_mse: 0.5450 - val_r_square: 0.5841 - val_rmse: 0.7383
# Epoch 149/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5795 - mae: 0.5561 - mse: 0.5795 - r_square: 0.5489 - rmse: 0.7612 - val_loss: 0.5579 - val_mae: 0.5167 - val_mse: 0.5579 - val_r_square: 0.5749 - val_rmse: 0.7469
# Epoch 150/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5537 - mae: 0.5421 - mse: 0.5537 - r_square: 0.5676 - rmse: 0.7441 - val_loss: 0.5185 - val_mae: 0.5057 - val_mse: 0.5185 - val_r_square: 0.6025 - val_rmse: 0.7201
# Epoch 151/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5576 - mae: 0.5444 - mse: 0.5576 - r_square: 0.5626 - rmse: 0.7467 - val_loss: 0.5153 - val_mae: 0.5046 - val_mse: 0.5153 - val_r_square: 0.6041 - val_rmse: 0.7179
# Epoch 152/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5547 - mae: 0.5435 - mse: 0.5547 - r_square: 0.5665 - rmse: 0.7448 - val_loss: 0.5092 - val_mae: 0.5082 - val_mse: 0.5092 - val_r_square: 0.6080 - val_rmse: 0.7136
# Epoch 153/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5691 - mae: 0.5521 - mse: 0.5691 - r_square: 0.5568 - rmse: 0.7543 - val_loss: 0.5096 - val_mae: 0.5070 - val_mse: 0.5096 - val_r_square: 0.6083 - val_rmse: 0.7138
# Epoch 154/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5427 - mae: 0.5356 - mse: 0.5427 - r_square: 0.5744 - rmse: 0.7366 - val_loss: 0.5370 - val_mae: 0.5033 - val_mse: 0.5370 - val_r_square: 0.5898 - val_rmse: 0.7328
# Epoch 155/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5467 - mae: 0.5385 - mse: 0.5467 - r_square: 0.5731 - rmse: 0.7393 - val_loss: 0.5189 - val_mae: 0.5094 - val_mse: 0.5189 - val_r_square: 0.6018 - val_rmse: 0.7203
# Epoch 156/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5463 - mae: 0.5370 - mse: 0.5463 - r_square: 0.5739 - rmse: 0.7391 - val_loss: 0.5347 - val_mae: 0.5001 - val_mse: 0.5347 - val_r_square: 0.5911 - val_rmse: 0.7313
# Epoch 157/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.5466 - mae: 0.5366 - mse: 0.5466 - r_square: 0.5746 - rmse: 0.7392 - val_loss: 0.5341 - val_mae: 0.5111 - val_mse: 0.5341 - val_r_square: 0.5920 - val_rmse: 0.7308
# Epoch 158/200
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.5516 - mae: 0.5390 - mse: 0.5516 - r_square: 0.5699 - rmse: 0.7426 - val_loss: 0.5373 - val_mae: 0.5065 - val_mse: 0.5373 - val_r_square: 0.5896 - val_rmse: 0.7330
# Epoch 158: early stopping
# Restoring model weights from the end of the best epoch: 138.
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4818 - mae: 0.5156 - mse: 0.4818 - r_square: 0.6183 - rmse: 0.6940
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4781 - mae: 0.5095 - mse: 0.4781 - r_square: 0.6325 - rmse: 0.6910
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4674 - mae: 0.5081 - mse: 0.4674 - r_square: 0.6202 - rmse: 0.6836
# Model 1 Metrics: {'train_loss': 1.3221794366836548, 'train_mse': 1.3221794366836548, 'train_mae': 0.915209949016571, 'train_rmse': 1.1498606204986572, 'train_r2': -0.04330216720700264, 'val_loss': 1.3706023693084717, 'val_mse': 1.3706023693084717, 'val_mae': 0.928507387638092, 'val_rmse': 1.170727252960205, 'val_r2': -0.03930312767624855, 'test_loss': 1.3264981508255005, 'test_mse': 1.3264981508255005, 'test_mae': 0.9184255003929138, 'test_rmse': 1.1517369747161865, 'test_r2': -0.03145939111709595}
# Model 2 Metrics: {'train_loss': 0.5019701719284058, 'train_mse': 0.5019701719284058, 'train_mae': 0.5026751756668091, 'train_rmse': 0.7084985375404358, 'train_r2': 0.6017364859580994, 'val_loss': 0.5311649441719055, 'val_mse': 0.5311649441719055, 'val_mae': 0.5194711685180664, 'val_rmse': 0.7288106083869934, 'val_r2': 0.5939550995826721, 'test_loss': 0.4826106131076813, 'test_mse': 0.4826106131076813, 'test_mae': 0.4981970489025116, 'test_rmse': 0.6947017908096313, 'test_r2': 0.6209831833839417}
# Model 3 Metrics: {'train_loss': 0.4822315573692322, 'train_mse': 0.4822315573692322, 'train_mae': 0.5141420364379883, 'train_rmse': 0.6944289207458496, 'train_r2': 0.6118369698524475, 'val_loss': 0.509125828742981, 'val_mse': 0.509125828742981, 'val_mae': 0.5265830755233765, 'val_rmse': 0.7135305404663086, 'val_r2': 0.6070765852928162, 'test_loss': 0.46791261434555054, 'test_mse': 0.46791261434555054, 'test_mae': 0.5108104944229126, 'test_rmse': 0.6840413808822632, 'test_r2': 0.6275721788406372}

# %%
def find_best_model(base_path):
    best_rmse = float('inf')
    best_folder = None

    # Walk through all directories and files in the base path
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file == f'{dataset_name}_metrics.txt':
                file_path = os.path.join(root, file)
                
                # Read metrics from the file
                with open(file_path, 'r') as f:
                    metrics = f.read()
                
                # Parse the metrics into a dictionary
                metrics_dict = {}
                for line in metrics.splitlines():
                    key, value = line.split(': ')
                    metrics_dict[key.strip()] = float(value.strip())
                
                # Check if the current folder has a better validation loss
                if metrics_dict['test_rmse'] < best_rmse:
                    best_rmse = metrics_dict['test_rmse']
                    best_folder = root
    
    return best_folder, best_rmse

# %%
import os

def rename_folder(old_folder_path):
    # Extract the base name of the old folder
    folder_name = os.path.basename(old_folder_path)
    
    # Create the new folder name by prepending "best_"
    new_folder_name = f"BEST_{folder_name}"
    
    # Get the parent directory of the old folder
    parent_dir = os.path.dirname(old_folder_path)
    
    # Create the full path for the new folder
    new_folder_path = os.path.join(parent_dir, new_folder_name)
    
    # Rename the folder
    os.rename(old_folder_path, new_folder_path)
    
    return new_folder_path

# %%
# Usage
base_path = f"logs/{dataset_name}/ViT_Regression"
best_folder, best_rmse = find_best_model(base_path)
best_folder = rename_folder(best_folder)
print(f"Best model folder: {best_folder}")
print(f"Best RMSE: {best_rmse}")
# Out:
# Best model folder: logs/california_housing/ViT_Regression\BEST_TINTO_Model3
# Best RMSE: 0.6840413808822632
